# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#SBML-FULL-model-ostreococcus" data-toc-modified-id="SBML-FULL-model-ostreococcus-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SBML FULL model ostreococcus</a></div><div class="lev1 toc-item"><a href="#Otauri-Models-from-Pathway-tools" data-toc-modified-id="Otauri-Models-from-Pathway-tools-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Otauri Models from Pathway tools</a></div><div class="lev2 toc-item"><a href="#conversion-from-SBML-to-Boltzmann-input-files" data-toc-modified-id="conversion-from-SBML-to-Boltzmann-input-files-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>conversion from SBML to Boltzmann input files</a></div><div class="lev2 toc-item"><a href="#Centeral-Metabolism-Rxn-for-MetaFlux-in-PT" data-toc-modified-id="Centeral-Metabolism-Rxn-for-MetaFlux-in-PT-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Centeral Metabolism Rxn for MetaFlux in PT</a></div><div class="lev2 toc-item"><a href="#Get-Chemical-Potential" data-toc-modified-id="Get-Chemical-Potential-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Get Chemical Potential</a></div><div class="lev1 toc-item"><a href="#Boltzmann-(Model-and-Simulation-)" data-toc-modified-id="Boltzmann-(Model-and-Simulation-)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Boltzmann (Model and Simulation )</a></div><div class="lev2 toc-item"><a href="#Run-Deterministic-Simulation" data-toc-modified-id="Run-Deterministic-Simulation-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Run Deterministic Simulation</a></div><div class="lev2 toc-item"><a href="#Analyze-Simulation-Results-for-centeral-Metabolism-of-O.-tuari" data-toc-modified-id="Analyze-Simulation-Results-for-centeral-Metabolism-of-O.-tuari-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Analyze Simulation Results for centeral Metabolism of O. tuari</a></div><div class="lev3 toc-item"><a href="#Derivatives-from-ODE-thermodynamic-optimization-simulation" data-toc-modified-id="Derivatives-from-ODE-thermodynamic-optimization-simulation-321"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Derivatives from ODE thermodynamic optimization simulation</a></div><div class="lev3 toc-item"><a href="#Likelihoods-from-Deterministic-Simulation" data-toc-modified-id="Likelihoods-from-Deterministic-Simulation-322"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Likelihoods from Deterministic Simulation</a></div><div class="lev3 toc-item"><a href="#Conversion-from-BiGG-ids-to-Biocyc" data-toc-modified-id="Conversion-from-BiGG-ids-to-Biocyc-323"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Conversion from BiGG ids to Biocyc</a></div><div class="lev2 toc-item"><a href="#Analyze-Metabolite-Levels-from-Deterministic-Simulation" data-toc-modified-id="Analyze-Metabolite-Levels-from-Deterministic-Simulation-33"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Analyze Metabolite Levels from Deterministic Simulation</a></div><div class="lev3 toc-item"><a href="#Find-Active-and-Variable-Metabolites" data-toc-modified-id="Find-Active-and-Variable-Metabolites-331"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Find Active and Variable Metabolites</a></div><div class="lev3 toc-item"><a href="#S.dot.net_likelihoods_steady_state" data-toc-modified-id="S.dot.net_likelihoods_steady_state-332"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>S.dot.net_likelihoods_steady_state</a></div><div class="lev3 toc-item"><a href="#Infer-Regulated-Reactions" data-toc-modified-id="Infer-Regulated-Reactions-333"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Infer Regulated Reactions</a></div><div class="lev2 toc-item"><a href="#Likelihoods-from-Stochastic-Simulation" data-toc-modified-id="Likelihoods-from-Stochastic-Simulation-34"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Likelihoods from Stochastic Simulation</a></div><div class="lev2 toc-item"><a href="#Read-in-Flux-Values-from-Stochastic-Simulation" data-toc-modified-id="Read-in-Flux-Values-from-Stochastic-Simulation-35"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Read in Flux Values from Stochastic Simulation</a></div><div class="lev2 toc-item"><a href="#Analyze-Metabolite-Levels-from-Stochastic-Simulation" data-toc-modified-id="Analyze-Metabolite-Levels-from-Stochastic-Simulation-36"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Analyze Metabolite Levels from Stochastic Simulation</a></div><div class="lev2 toc-item"><a href="#Compare-ODE-and-Stochastic-Metabolite-Concentrations" data-toc-modified-id="Compare-ODE-and-Stochastic-Metabolite-Concentrations-37"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Compare ODE and Stochastic Metabolite Concentrations</a></div><div class="lev2 toc-item"><a href="#Display-Pathway-Predictions" data-toc-modified-id="Display-Pathway-Predictions-38"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Display Pathway Predictions</a></div><div class="lev2 toc-item"><a href="#Power-and-Fluxes" data-toc-modified-id="Power-and-Fluxes-39"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Power and Fluxes</a></div><div class="lev1 toc-item"><a href="#Boltzmann-to-sbml-file-for-biocyc" data-toc-modified-id="Boltzmann-to-sbml-file-for-biocyc-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Boltzmann to sbml file for biocyc</a></div>

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import subprocess
import re
import os
import mentos
from IPython.core.display import display
#from ipynb_latex_setup import *
# %matplotlib inline
import cobra
#%matplotlib pdf
#matplotlib.matplotlib_fname()
#import matplotlib.rcsetup as rcsetup
#print(rcsetup.all_backends)

# %% [markdown]
# # SBML FULL model ostreococcus

# %%
import json
import os
import cobra
modeldir = '/Users/kuma889/Projects/Boltzmann/Boltz/Ostreococcus/SBML'
full_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'Libourel_Otauri_SBMLModel.xml'))
#core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'Otauri.COBRA-sbml3.xml'))
full_model.optimize()
# Out:
# -------------------------------------------------------------------
# UnicodeEncodeError                Traceback (most recent call last)
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/core/solution.pyc in _repr_html_(self)
#      94                         'value {:.3f}</strong><br>{}'
#      95                         .format(self.objective_value,
# ---> 96                                 self.to_frame()._repr_html_()))
#      97         else:
#      98             html = '<strong><em>{}</em> solution</strong>'.format(self.status)
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xd7' in position 1374: ordinal not in range(128)
# <Solution 0.275 at 0x110405210>

# %% [markdown]
# #  Otauri Models from Pathway tools

# %%
import json
import os
import cobra
modeldir = './'
core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'PPP_Gly_TCA_A-COA-Bys.sbml'))
#core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'central_metabolism_ST_COBRA_sbml3.xml'))
core_model.objective= 'RXN__45__1641'
core_model.optimize()
#core_model.metabolites.Triacylglycerols_c
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-c9c1bcb68958> in <module>()
#       3 import cobra
#       4 modeldir = './'
# ----> 5 core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'PPP_Gly_TCA_A-COA-Bys.sbml'))
#       6 #core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'central_metabolism_ST_COBRA_sbml3.xml'))
#       7 core_model.objective= 'RXN__45__1641'
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/io/sbml3.pyc in read_sbml_model(filename, number, **kwargs)
#     566     if not _with_lxml:
#     567         warn("Install lxml for faster SBML I/O", ImportWarning)
# --> 568     xmlfile = parse_stream(filename)
#     569     xml = xmlfile.getroot()
#     570     # use libsbml if not l3v1 with fbc v2
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/io/sbml3.pyc in parse_stream(filename)
#     150                 return parse(infile)
#     151         else:
# --> 152             return parse(filename)
#     153     except ParseError as e:
#     154         raise CobraSBMLError("Malformed XML file: " + str(e))
#
# src/lxml/lxml.etree.pyx in lxml.etree.parse (src/lxml/lxml.etree.c:81117)()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument (src/lxml/lxml.etree.c:117848)()
#
# src/lxml/parser.pxi in lxml.etree._parseDocumentFromURL (src/lxml/lxml.etree.c:118195)()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFile (src/lxml/lxml.etree.c:117107)()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile (src/lxml/lxml.etree.c:111653)()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc (src/lxml/lxml.etree.c:105109)()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult (src/lxml/lxml.etree.c:106817)()
#
# src/lxml/parser.pxi in lxml.etree._raiseParseError (src/lxml/lxml.etree.c:105628)()
#
# IOError: Error reading file './PPP_Gly_TCA_A-COA-Bys.sbml': failed to load external entity "./PPP_Gly_TCA_A-COA-Bys.sbml"

# %% [markdown]
# ## conversion from SBML to Boltzmann input files

# %%
import libsbml
r = libsbml.SBMLReader()
d = r.readSBML('modeldir/')
if d.getNumErrors() > 0 :
    print (d.getError(0).getMessage())
else : 
    m = d.getModel()
deltag = pd.read_table('/Users/kuma889/Projects/Boltzmann/Boltz/Ostreococcus/SBML/central_metabolism_dg0.tab', index_col='ID')
deltag
# Out:
# File unreadable.
#                                                                                        Name  \
# ID
# FUMHYDR-RXN                               (<i>S</i>)-malate  &larr;  fumarate + H<sub>2<...
# MALATE-DEH-RXN                            (<i>S</i>)-malate + NAD<sup>+</sup>  &harr;  o...
# 2OXOGLUTARATEDEH-RXN                      2-oxoglutarate + coenzyme A + NAD<sup>+</sup> ...
# ACONITATEHYDR-RXN                         <i>cis</i>-aconitate + H<sub>2</sub>O  &harr; ...
# CITSYN-RXN                                acetyl-CoA + oxaloacetate + H<sub>2</sub>O  &r...
# ACONITATEDEHYDR-RXN                       citrate  &harr;  <i>cis</i>-aconitate + H<sub>...
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN         D-<i>threo</i>-isocitrate + NAD<sup>+</sup>  &...
# SUCCCOASYN-RXN                            succinate + ATP + coenzyme A  &harr;  succinyl...
# RXN-14971                                 succinate<SUB>[in]</SUB> + an electron-transfe...
# RXN0-1132                                 a [pyruvate dehydrogenase E2 protein] <i>N<sup...
# RXN0-1133                                 acetyl-CoA + a [pyruvate dehydrogenase E2 prot...
# RXN0-1134                                 pyruvate + a [pyruvate dehydrogenase E2 protei...
# PSII-RXN                                  2 a plastoquinol<SUB>[membrane]</SUB> + 4 H<SU...
# 1.18.1.2-RXN                              2 a reduced ferredoxin [iron-sulfur] cluster<S...
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN  2 an oxidized plastocyanin<SUB>[in]</SUB> + a ...
# RXN-15479                                 an oxidized plastocyanin<SUB>[in]</SUB> + a re...
# TRANSALDOL-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# 6PGLUCONOLACT-RXN                         6-phospho D-glucono-1,5-lactone + H<sub>2</sub...
# RXN-9952                                  D-gluconate 6-phosphate + NADP<sup>+</sup>  &r...
# GLU6PDEHYDROG-RXN                         D-glucopyranose 6-phosphate + NADP<sup>+</sup>...
# 3PGAREARR-RXN                             2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 2PGADEHYDRAT-RXN                          2-phospho-D-glycerate  &harr;  phospho<i>enol<...
# PEPDEPHOS-RXN                             pyruvate + ATP  &larr;  phospho<i>enol</i>pyru...
# RXN-15513                                 2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 6PFRUCTPHOS-RXN                           ATP + &beta;-D-fructofuranose 6-phosphate  &ra...
# PGLUCISOM-RXN                             D-glucopyranose 6-phosphate  &harr;  &beta;-D-...
# GAPOXNPHOSPHN-RXN                         D-glyceraldehyde 3-phosphate + NAD<sup>+</sup>...
# PEPSYNTH-RXN                              pyruvate + ATP + H<sub>2</sub>O  &rarr;  phosp...
# 1.1.1.8-RXN                               <i>sn</i>-glycerol 3-phosphate + NAD<sup>+</su...
# RXN-15745                                 <i>sn</i>-glycerol 3-phosphate<SUB>[in]</SUB> ...
# RXN-12383                                 2 a 1,2-diacyl-<i>sn</i>-glycerol  &harr;  a t...
# PHOSPHATIDATE-PHOSPHATASE-RXN             a 1,2-diacyl-<i>sn</i>-glycerol 3-phosphate + ...
# RXN-1381                                  a long-chain acyl-CoA + <i>sn</i>-glycerol 3-p...
# RXN-1623                                  a long-chain acyl-CoA + a 1-acyl-<i>sn</i>-gly...
# RXN-1641                                  a phosphatidylcholine + a 1,2-diacyl-<i>sn</i>...
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN      an acyl-CoA + a 1,2-diacyl-<i>sn</i>-glycerol ...
# RXN-12959                                 CTP + a 1,2-diacyl-<i>sn</i>-glycerol  &rarr; ...
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN     2 3-phospho-D-glycerate + 2 H<SUP>+</SUP>  &la...
# PHOSPHORIBULOKINASE-RXN                   D-ribulose 5-phosphate + ATP  &rarr;  D-ribulo...
# 2TRANSKETO-RXN                            D-erythrose 4-phosphate + D-xylulose 5-phospha...
# RIB5PISOM-RXN                             D-ribose 5-phosphate  &harr;  D-ribulose 5-pho...
# RIBULP3EPIM-RXN                           D-ribulose 5-phosphate  &harr;  D-xylulose 5-p...
# 1TRANSKETO-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# PHOSGLYPHOS-RXN                           3-phospho-D-glycerate + ATP  &harr;  3-phospho...
# TRIOSEPISOMERIZATION-RXN                  D-glyceraldehyde 3-phosphate  &harr;  glyceron...
# F16ALDOLASE-RXN                           fructose 1,6-bisphosphate  &harr;  glycerone p...
# F16BDEPHOS-RXN                            fructose 1,6-bisphosphate + H<sub>2</sub>O  &r...
# 1.2.1.13-RXN                              D-glyceraldehyde 3-phosphate + NADP<sup>+</sup...
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN          D-sedoheptulose-1,7-bisphosphate + H<sub>2</su...
# SEDOBISALDOL-RXN                          glycerone phosphate + D-erythrose 4-phosphate ...
#
#                                                                       Matches  \
# ID
# FUMHYDR-RXN                                                          PWY-5690
# MALATE-DEH-RXN                                                       PWY-5690
# 2OXOGLUTARATEDEH-RXN                                                 PWY-5690
# ACONITATEHYDR-RXN                                                    PWY-5690
# CITSYN-RXN                                                           PWY-5690
# ACONITATEDEHYDR-RXN                                                  PWY-5690
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN                                    PWY-5690
# SUCCCOASYN-RXN                                                       PWY-5690
# RXN-14971                                                            PWY-5690
# RXN0-1132                                                      PYRUVDEHYD-PWY
# RXN0-1133                                                      PYRUVDEHYD-PWY
# RXN0-1134                                                      PYRUVDEHYD-PWY
# PSII-RXN                                                              PWY-101
# 1.18.1.2-RXN                                                          PWY-101
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN                              PWY-101
# RXN-15479                                                             PWY-101
# TRANSALDOL-RXN                                        PENTOSE-P-PWY, PWY-5723
# 6PGLUCONOLACT-RXN                                               PENTOSE-P-PWY
# RXN-9952                                                        PENTOSE-P-PWY
# GLU6PDEHYDROG-RXN                                               PENTOSE-P-PWY
# 3PGAREARR-RXN                                            GLYCOLYSIS, PWY-5723
# 2PGADEHYDRAT-RXN                                         GLYCOLYSIS, PWY-5723
# PEPDEPHOS-RXN                                            GLYCOLYSIS, PWY-5723
# RXN-15513                                                          GLYCOLYSIS
# 6PFRUCTPHOS-RXN                                                    GLYCOLYSIS
# PGLUCISOM-RXN                                                      GLYCOLYSIS
# GAPOXNPHOSPHN-RXN                                                  GLYCOLYSIS
# PEPSYNTH-RXN                                                       GLYCOLYSIS
# 1.1.1.8-RXN                                                          PWY-6118
# RXN-15745                                                            PWY-6118
# RXN-12383                                                        TRIGLSYN-PWY
# PHOSPHATIDATE-PHOSPHATASE-RXN                                    TRIGLSYN-PWY
# RXN-1381                                                         TRIGLSYN-PWY
# RXN-1623                                                         TRIGLSYN-PWY
# RXN-1641                                                         TRIGLSYN-PWY
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN                             TRIGLSYN-PWY
# RXN-12959                                                        TRIGLSYN-PWY
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN                    CALVIN-PWY, PWY-5723
# PHOSPHORIBULOKINASE-RXN                                  CALVIN-PWY, PWY-5723
# 2TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIB5PISOM-RXN                             CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIBULP3EPIM-RXN                           CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# 1TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# PHOSGLYPHOS-RXN                                        CALVIN-PWY, GLYCOLYSIS
# TRIOSEPISOMERIZATION-RXN                               CALVIN-PWY, GLYCOLYSIS
# F16ALDOLASE-RXN                                        CALVIN-PWY, GLYCOLYSIS
# F16BDEPHOS-RXN                                         CALVIN-PWY, GLYCOLYSIS
# 1.2.1.13-RXN                                                       CALVIN-PWY
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN                                   CALVIN-PWY
# SEDOBISALDOL-RXN                                                   CALVIN-PWY
#
#                                           Gibbs-0  Unnamed: 4
# ID
# FUMHYDR-RXN                                 0.613         nan
# MALATE-DEH-RXN                               4.46         nan
# 2OXOGLUTARATEDEH-RXN                        -11.4         nan
# ACONITATEHYDR-RXN                           -3.13         nan
# CITSYN-RXN                                  -10.5         nan
# ACONITATEDEHYDR-RXN                          3.35         nan
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN            1.62         nan
# SUCCCOASYN-RXN                              -1.05         nan
# RXN-14971                                    22.8         nan
# RXN0-1132                                    19.4         nan
# RXN0-1133                                   -20.5         nan
# RXN0-1134                                   -49.9         nan
# PSII-RXN                                      nan         nan
# 1.18.1.2-RXN                                 9.63         nan
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN      nan         nan
# RXN-15479                                     nan         nan
# TRANSALDOL-RXN                              -2.92         nan
# 6PGLUCONOLACT-RXN                           -7.36         nan
# RXN-9952                                    -1.38         nan
# GLU6PDEHYDROG-RXN                           -5.93         nan
# 3PGAREARR-RXN                               -1.32         nan
# 2PGADEHYDRAT-RXN                           -0.187         nan
# PEPDEPHOS-RXN                               -2.23         nan
# RXN-15513                                   -1.32         nan
# 6PFRUCTPHOS-RXN                             -14.5         nan
# PGLUCISOM-RXN                                1.38         nan
# GAPOXNPHOSPHN-RXN                           -15.2         nan
# PEPSYNTH-RXN                                -9.58         nan
# 1.1.1.8-RXN                                  4.15         nan
# RXN-15745                                    12.5         nan
# RXN-12383                                       0         nan
# PHOSPHATIDATE-PHOSPHATASE-RXN               -3.05         nan
# RXN-1381                                      253         nan
# RXN-1623                                      325         nan
# RXN-1641                                        0         nan
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN          325         nan
# RXN-12959                                   -99.5         nan
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN        4.14         nan
# PHOSPHORIBULOKINASE-RXN                     -17.3         nan
# 2TRANSKETO-RXN                               3.96         nan
# RIB5PISOM-RXN                               -6.13         nan
# RIBULP3EPIM-RXN                                 0         nan
# 1TRANSKETO-RXN                               1.23         nan
# PHOSGLYPHOS-RXN                             -7.51         nan
# TRIOSEPISOMERIZATION-RXN                    -1.83         nan
# F16ALDOLASE-RXN                              8.23         nan
# F16BDEPHOS-RXN                               6.89         nan
# 1.2.1.13-RXN                                -16.4         nan
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN             9.71         nan
# SEDOBISALDOL-RXN                            -8.13         nan

# %%
import re
class sbml2boltzmann:
    def __init__( self, sbml, deltag ):
        self.sbml = sbml
        self.deltag = deltag['Gibbs-0'].to_dict()
        self.ordRE = re.compile('__([0-9]+)__')
    def repl( self, matchobj ):
        return chr(int(matchobj.group(1)))
   
    def unmunge( self, sbmlid ):
        return self.ordRE.sub( self.repl, sbmlid)
   
    def get_met_comp( self, speciesId ):
        s = self.sbml.getSpecies(speciesId)
        if s.getCompartment() == 'CCO__45__CYTOSOL':
            return self.unmunge( s.getId() + ':' + s.getCompartment() )
        else:
            return self.unmunge( s.getId()).replace('[',':').rstrip(']')
       
    def write_compartment( self, filename ):
        with open(filename, 'w') as out:
            i = 1
            for comp in self.sbml.getListOfCompartments():
                out.write('{}\t{}\tliters\t0\tV\n'.format(self.unmunge(comp.getId()), float(i)))
                i +=1
    def write_concentrations( self, filename, volume=1.0e-15, conc_units=1.0e-9, default_conc=1.1111111e-01):
        with open(filename, 'w') as out:
            out.write('VOLUME\t{}\n'.format(volume))
            out.write('CONC_UNITS\t{}\n'.format(conc_units))
            for species in self.sbml.getListOfSpecies():
                if species.getBoundaryCondition():
                    boundary="F"
                else :
                    boundary="V"
                out.write('{}\t{}\t{}\n'.format(self.get_met_comp(species.getId()), default_conc, boundary))
   
    def getDeltaG( self, rxnName ):
        if rxnName in self.deltag:
            return self.deltag[rxnName]
        else:
            return 0.0
    def write_reactions( self, filename):
        with open(filename, 'w') as out:
            for rxn in self.sbml.getListOfReactions():
                out.write('REACTION\t{}\n'.format(rxn.getName()))
                out.write('LEFT\t{}\n'.format(' + '.join([self.get_met_comp(sr.getSpecies()) 
                                                         for sr in rxn.getListOfReactants()])))
                out.write('RIGHT\t{}\n'.format(' + '.join([self.get_met_comp(sr.getSpecies()) 
                                                         for sr in rxn.getListOfProducts()])))
                out.write('DGZERO\t{}\n'.format(self.getDeltaG(rxn.getName())))
                out.write('DGZERO_UNITS\t{}\n'.format('KCAL/MOL'))
                out.write('//\n')
                         
s2b = sbml2boltzmann(m, deltag)
s2b.get_met_comp('M_CPD__45__548')
s2b.write_compartment('/Users/kuma889/Projects/Ostreococcus/SBML/central_metabolism_dg0_test.cmpts')
s2b.write_concentrations('/Users/kuma889/Projects/Ostreococcus/SBML/central_metabolism_dg0_testt.in')
s2b.write_reactions('/Users/kuma889/Projects/Ostreococcus/SBML/central_metabolism_dg0_rxns.dat')

# %% [markdown]
# ## Centeral Metabolism Rxn for MetaFlux in PT

# %%
import pandas as pd
cm=pd.read_table(os.path.join(modeldir, "central_metabolism_st.tab"), index_col="ID")
cm
with open(os.path.join(modeldir,"central_metabolism.rxn"), "w") as out:
    out.write('\n'.join(cm.index))
cm
# Out:
#                                                                                        Name  \
# ID
# FUMHYDR-RXN                               (<i>S</i>)-malate  &larr;  fumarate + H<sub>2<...
# MALATE-DEH-RXN                            (<i>S</i>)-malate + NAD<sup>+</sup>  &harr;  o...
# 2OXOGLUTARATEDEH-RXN                      2-oxoglutarate + coenzyme A + NAD<sup>+</sup> ...
# ACONITATEHYDR-RXN                         <i>cis</i>-aconitate + H<sub>2</sub>O  &harr; ...
# CITSYN-RXN                                acetyl-CoA + oxaloacetate + H<sub>2</sub>O  &r...
# ACONITATEDEHYDR-RXN                       citrate  &harr;  <i>cis</i>-aconitate + H<sub>...
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN         D-<i>threo</i>-isocitrate + NAD<sup>+</sup>  &...
# SUCCCOASYN-RXN                            succinate + ATP + coenzyme A  &harr;  succinyl...
# RXN-14971                                 succinate<SUB>[in]</SUB> + an electron-transfe...
# RXN0-1132                                 a [pyruvate dehydrogenase E2 protein] <i>N<sup...
# RXN0-1133                                 acetyl-CoA + a [pyruvate dehydrogenase E2 prot...
# RXN0-1134                                 pyruvate + a [pyruvate dehydrogenase E2 protei...
# PSII-RXN                                  2 a plastoquinol<SUB>[membrane]</SUB> + 4 H<SU...
# 1.18.1.2-RXN                              2 a reduced ferredoxin [iron-sulfur] cluster<S...
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN  2 an oxidized plastocyanin<SUB>[in]</SUB> + a ...
# RXN-15479                                 an oxidized plastocyanin<SUB>[in]</SUB> + a re...
# TRANSALDOL-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# 6PGLUCONOLACT-RXN                         6-phospho D-glucono-1,5-lactone + H<sub>2</sub...
# RXN-9952                                  D-gluconate 6-phosphate + NADP<sup>+</sup>  &r...
# GLU6PDEHYDROG-RXN                         D-glucopyranose 6-phosphate + NADP<sup>+</sup>...
# 3PGAREARR-RXN                             2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 2PGADEHYDRAT-RXN                          2-phospho-D-glycerate  &harr;  phospho<i>enol<...
# PEPDEPHOS-RXN                             pyruvate + ATP  &larr;  phospho<i>enol</i>pyru...
# RXN-15513                                 2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 6PFRUCTPHOS-RXN                           ATP + &beta;-D-fructofuranose 6-phosphate  &ra...
# PGLUCISOM-RXN                             D-glucopyranose 6-phosphate  &harr;  &beta;-D-...
# GAPOXNPHOSPHN-RXN                         D-glyceraldehyde 3-phosphate + NAD<sup>+</sup>...
# PEPSYNTH-RXN                              pyruvate + ATP + H<sub>2</sub>O  &rarr;  phosp...
# 1.1.1.8-RXN                               <i>sn</i>-glycerol 3-phosphate + NAD<sup>+</su...
# RXN-15745                                 <i>sn</i>-glycerol 3-phosphate<SUB>[in]</SUB> ...
# RXN-12383                                 2 a 1,2-diacyl-<i>sn</i>-glycerol  &harr;  a t...
# PHOSPHATIDATE-PHOSPHATASE-RXN             a 1,2-diacyl-<i>sn</i>-glycerol 3-phosphate + ...
# RXN-1381                                  a long-chain acyl-CoA + <i>sn</i>-glycerol 3-p...
# RXN-1623                                  a long-chain acyl-CoA + a 1-acyl-<i>sn</i>-gly...
# RXN-1641                                  a phosphatidylcholine + a 1,2-diacyl-<i>sn</i>...
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN      an acyl-CoA + a 1,2-diacyl-<i>sn</i>-glycerol ...
# RXN-12959                                 CTP + a 1,2-diacyl-<i>sn</i>-glycerol  &rarr; ...
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN     2 3-phospho-D-glycerate + 2 H<SUP>+</SUP>  &la...
# PHOSPHORIBULOKINASE-RXN                   D-ribulose 5-phosphate + ATP  &rarr;  D-ribulo...
# 2TRANSKETO-RXN                            D-erythrose 4-phosphate + D-xylulose 5-phospha...
# RIB5PISOM-RXN                             D-ribose 5-phosphate  &harr;  D-ribulose 5-pho...
# RIBULP3EPIM-RXN                           D-ribulose 5-phosphate  &harr;  D-xylulose 5-p...
# 1TRANSKETO-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# PHOSGLYPHOS-RXN                           3-phospho-D-glycerate + ATP  &harr;  3-phospho...
# TRIOSEPISOMERIZATION-RXN                  D-glyceraldehyde 3-phosphate  &harr;  glyceron...
# F16ALDOLASE-RXN                           fructose 1,6-bisphosphate  &harr;  glycerone p...
# F16BDEPHOS-RXN                            fructose 1,6-bisphosphate + H<sub>2</sub>O  &r...
# 1.2.1.13-RXN                              D-glyceraldehyde 3-phosphate + NADP<sup>+</sup...
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN          D-sedoheptulose-1,7-bisphosphate + H<sub>2</su...
# SEDOBISALDOL-RXN                          glycerone phosphate + D-erythrose 4-phosphate ...
#
#                                                                       Matches  \
# ID
# FUMHYDR-RXN                                                          PWY-5690
# MALATE-DEH-RXN                                                       PWY-5690
# 2OXOGLUTARATEDEH-RXN                                                 PWY-5690
# ACONITATEHYDR-RXN                                                    PWY-5690
# CITSYN-RXN                                                           PWY-5690
# ACONITATEDEHYDR-RXN                                                  PWY-5690
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN                                    PWY-5690
# SUCCCOASYN-RXN                                                       PWY-5690
# RXN-14971                                                            PWY-5690
# RXN0-1132                                                      PYRUVDEHYD-PWY
# RXN0-1133                                                      PYRUVDEHYD-PWY
# RXN0-1134                                                      PYRUVDEHYD-PWY
# PSII-RXN                                                              PWY-101
# 1.18.1.2-RXN                                                          PWY-101
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN                              PWY-101
# RXN-15479                                                             PWY-101
# TRANSALDOL-RXN                                        PENTOSE-P-PWY, PWY-5723
# 6PGLUCONOLACT-RXN                                               PENTOSE-P-PWY
# RXN-9952                                                        PENTOSE-P-PWY
# GLU6PDEHYDROG-RXN                                               PENTOSE-P-PWY
# 3PGAREARR-RXN                                            GLYCOLYSIS, PWY-5723
# 2PGADEHYDRAT-RXN                                         GLYCOLYSIS, PWY-5723
# PEPDEPHOS-RXN                                            GLYCOLYSIS, PWY-5723
# RXN-15513                                                          GLYCOLYSIS
# 6PFRUCTPHOS-RXN                                                    GLYCOLYSIS
# PGLUCISOM-RXN                                                      GLYCOLYSIS
# GAPOXNPHOSPHN-RXN                                                  GLYCOLYSIS
# PEPSYNTH-RXN                                                       GLYCOLYSIS
# 1.1.1.8-RXN                                                          PWY-6118
# RXN-15745                                                            PWY-6118
# RXN-12383                                                        TRIGLSYN-PWY
# PHOSPHATIDATE-PHOSPHATASE-RXN                                    TRIGLSYN-PWY
# RXN-1381                                                         TRIGLSYN-PWY
# RXN-1623                                                         TRIGLSYN-PWY
# RXN-1641                                                         TRIGLSYN-PWY
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN                             TRIGLSYN-PWY
# RXN-12959                                                        TRIGLSYN-PWY
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN                    CALVIN-PWY, PWY-5723
# PHOSPHORIBULOKINASE-RXN                                  CALVIN-PWY, PWY-5723
# 2TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIB5PISOM-RXN                             CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIBULP3EPIM-RXN                           CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# 1TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# PHOSGLYPHOS-RXN                                        CALVIN-PWY, GLYCOLYSIS
# TRIOSEPISOMERIZATION-RXN                               CALVIN-PWY, GLYCOLYSIS
# F16ALDOLASE-RXN                                        CALVIN-PWY, GLYCOLYSIS
# F16BDEPHOS-RXN                                         CALVIN-PWY, GLYCOLYSIS
# 1.2.1.13-RXN                                                       CALVIN-PWY
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN                                   CALVIN-PWY
# SEDOBISALDOL-RXN                                                   CALVIN-PWY
#
#                                           Unnamed: 3
# ID
# FUMHYDR-RXN                                      NaN
# MALATE-DEH-RXN                                   NaN
# 2OXOGLUTARATEDEH-RXN                             NaN
# ACONITATEHYDR-RXN                                NaN
# CITSYN-RXN                                       NaN
# ACONITATEDEHYDR-RXN                              NaN
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN                NaN
# SUCCCOASYN-RXN                                   NaN
# RXN-14971                                        NaN
# RXN0-1132                                        NaN
# RXN0-1133                                        NaN
# RXN0-1134                                        NaN
# PSII-RXN                                         NaN
# 1.18.1.2-RXN                                     NaN
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN         NaN
# RXN-15479                                        NaN
# TRANSALDOL-RXN                                   NaN
# 6PGLUCONOLACT-RXN                                NaN
# RXN-9952                                         NaN
# GLU6PDEHYDROG-RXN                                NaN
# 3PGAREARR-RXN                                    NaN
# 2PGADEHYDRAT-RXN                                 NaN
# PEPDEPHOS-RXN                                    NaN
# RXN-15513                                        NaN
# 6PFRUCTPHOS-RXN                                  NaN
# PGLUCISOM-RXN                                    NaN
# GAPOXNPHOSPHN-RXN                                NaN
# PEPSYNTH-RXN                                     NaN
# 1.1.1.8-RXN                                      NaN
# RXN-15745                                        NaN
# RXN-12383                                        NaN
# PHOSPHATIDATE-PHOSPHATASE-RXN                    NaN
# RXN-1381                                         NaN
# RXN-1623                                         NaN
# RXN-1641                                         NaN
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN             NaN
# RXN-12959                                        NaN
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN            NaN
# PHOSPHORIBULOKINASE-RXN                          NaN
# 2TRANSKETO-RXN                                   NaN
# RIB5PISOM-RXN                                    NaN
# RIBULP3EPIM-RXN                                  NaN
# 1TRANSKETO-RXN                                   NaN
# PHOSGLYPHOS-RXN                                  NaN
# TRIOSEPISOMERIZATION-RXN                         NaN
# F16ALDOLASE-RXN                                  NaN
# F16BDEPHOS-RXN                                   NaN
# 1.2.1.13-RXN                                     NaN
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN                 NaN
# SEDOBISALDOL-RXN                                 NaN

# %% [markdown]
# ## Get Chemical Potential

# %%
import pandas as pd
from IPython.display import HTML
import libsbml
#r = str(to_unicode(
#            to_bytes(
#                requests.get('http://bigg.ucsd.edu/static/models/iJO1366.xml').text,
#                'ascii','ignore')))


#d = libsbml.SBMLReader().readSBMLFromString(r)
d = libsbml.SBMLReader().readSBML('/Users/kuma889/Projects/Boltzmann/MENTOS/Core/iJO1366.xml')
iJO1366_sbml= d.getModel()
iJO1366 = cobra.io.read_sbml_model('/Users/kuma889/Projects/Boltzmann/MENTOS/Core/iJO1366.xml')
online_supp = 'http://onlinelibrary.wiley.com/store/10.1038/msb4100155/asset/supinfo/msb4100155-sup-0003.xls?v=1&s=d6fe37a9ffd941ef5bc27013b9fa8868482e2d19'
local_supp = '/Users/kuma889/Projects/Boltzmann/MENTOS/Core/msb4100155-sup-0003.xls'
metG = pd.read_excel(local_supp, 
                     sheetname='compounds').rename(columns=lambda x: x.strip()).set_index('abbreviation')
metG.index = metG.index.str.replace('-','__').str.replace('__C','_C')
ijomets = [m.id for m in iJO1366.metabolites]
umets = pd.DataFrame({'universal_BiGG':[m.id[:-2] for m in iJO1366.metabolites]},index=ijomets)
mu0 = umets.join(other=metG, on='universal_BiGG')['formation delta G (pH 7)' ].replace('Not calculated',np.nan).dropna()
print(len(mu0))
display(HTML(mu0.to_frame().to_html()))

idx = fullS.index.intersection(mu0.index)

deltaG0 = fullS.loc[idx].T.dot(mu0[idx])
deltaG0.to_frame()
# Out:
# 1436
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>formation delta G (pH 7)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10fthf_c</th>
#       <td>-144.2810</td>
#     </tr>
#     <tr>
#       <th>12dgr120_c</th>
#       <td>-157.8860</td>
#     </tr>
#     <tr>
#       <th>12dgr140_c</th>
#       <td>-151.3050</td>
#     </tr>
#     <tr>
#       <th>12dgr141_c</th>
#       <td>-106.6220</td>
#     </tr>
#     <tr>
#       <th>12dgr160_c</th>
#       <td>-144.7230</td>
#     </tr>
#     <tr>
#       <th>12dgr161_c</th>
#       <td>-100.0410</td>
#     </tr>
#     <tr>
#       <th>12dgr180_c</th>
#       <td>-138.1420</td>
#     </tr>
#     <tr>
#       <th>12dgr181_c</th>
#       <td>-93.4598</td>
#     </tr>
#     <tr>
#       <th>12ppd__R_c</th>
#       <td>-79.6929</td>
#     </tr>
#     <tr>
#       <th>12ppd__S_c</th>
#       <td>-79.6929</td>
#     </tr>
#     <tr>
#       <th>13dpg_c</th>
#       <td>-585.8110</td>
#     </tr>
#     <tr>
#       <th>14glucan_c</th>
#       <td>-1006.5000</td>
#     </tr>
#     <tr>
#       <th>15dap_c</th>
#       <td>-4.4171</td>
#     </tr>
#     <tr>
#       <th>1ddecg3p_c</th>
#       <td>-348.7750</td>
#     </tr>
#     <tr>
#       <th>1hdec9eg3p_c</th>
#       <td>-319.8530</td>
#     </tr>
#     <tr>
#       <th>1hdecg3p_c</th>
#       <td>-342.1940</td>
#     </tr>
#     <tr>
#       <th>1odec11eg3p_c</th>
#       <td>-316.5620</td>
#     </tr>
#     <tr>
#       <th>1odecg3p_c</th>
#       <td>-338.9040</td>
#     </tr>
#     <tr>
#       <th>1pyr5c_c</th>
#       <td>-60.2665</td>
#     </tr>
#     <tr>
#       <th>1tdec7eg3p_c</th>
#       <td>-323.1440</td>
#     </tr>
#     <tr>
#       <th>1tdecg3p_c</th>
#       <td>-345.4850</td>
#     </tr>
#     <tr>
#       <th>23dappa_c</th>
#       <td>-89.0161</td>
#     </tr>
#     <tr>
#       <th>23ddhb_c</th>
#       <td>-126.7850</td>
#     </tr>
#     <tr>
#       <th>23dhb_c</th>
#       <td>-131.6250</td>
#     </tr>
#     <tr>
#       <th>23dhba_c</th>
#       <td>-335.8130</td>
#     </tr>
#     <tr>
#       <th>23dhbzs_c</th>
#       <td>-198.7250</td>
#     </tr>
#     <tr>
#       <th>23dhdp_c</th>
#       <td>-134.6010</td>
#     </tr>
#     <tr>
#       <th>23dhmb_c</th>
#       <td>-160.7870</td>
#     </tr>
#     <tr>
#       <th>23dhmp_c</th>
#       <td>-159.1420</td>
#     </tr>
#     <tr>
#       <th>23doguln_c</th>
#       <td>-247.1760</td>
#     </tr>
#     <tr>
#       <th>25aics_c</th>
#       <td>-486.8860</td>
#     </tr>
#     <tr>
#       <th>25dkglcn_c</th>
#       <td>-249.6670</td>
#     </tr>
#     <tr>
#       <th>25drapp_c</th>
#       <td>-326.1570</td>
#     </tr>
#     <tr>
#       <th>26dap__LL_c</th>
#       <td>-163.7430</td>
#     </tr>
#     <tr>
#       <th>26dap__M_c</th>
#       <td>-163.7430</td>
#     </tr>
#     <tr>
#       <th>2agpe120_c</th>
#       <td>-331.8970</td>
#     </tr>
#     <tr>
#       <th>2agpe140_c</th>
#       <td>-328.6060</td>
#     </tr>
#     <tr>
#       <th>2agpe141_c</th>
#       <td>-306.2650</td>
#     </tr>
#     <tr>
#       <th>2agpe160_c</th>
#       <td>-325.3160</td>
#     </tr>
#     <tr>
#       <th>2agpe161_c</th>
#       <td>-302.9740</td>
#     </tr>
#     <tr>
#       <th>2agpe180_c</th>
#       <td>-322.0250</td>
#     </tr>
#     <tr>
#       <th>2agpe181_c</th>
#       <td>-299.6840</td>
#     </tr>
#     <tr>
#       <th>2agpg120_c</th>
#       <td>-403.3110</td>
#     </tr>
#     <tr>
#       <th>2agpg140_c</th>
#       <td>-400.0200</td>
#     </tr>
#     <tr>
#       <th>2agpg141_c</th>
#       <td>-377.6790</td>
#     </tr>
#     <tr>
#       <th>2agpg160_c</th>
#       <td>-396.7300</td>
#     </tr>
#     <tr>
#       <th>2agpg161_c</th>
#       <td>-374.3880</td>
#     </tr>
#     <tr>
#       <th>2agpg180_c</th>
#       <td>-393.4390</td>
#     </tr>
#     <tr>
#       <th>2agpg181_c</th>
#       <td>-371.0980</td>
#     </tr>
#     <tr>
#       <th>2ahbut_c</th>
#       <td>-151.1490</td>
#     </tr>
#     <tr>
#       <th>2amsa_c</th>
#       <td>-114.7020</td>
#     </tr>
#     <tr>
#       <th>2aobut_c</th>
#       <td>-116.2480</td>
#     </tr>
#     <tr>
#       <th>2cpr5p_c</th>
#       <td>-391.5870</td>
#     </tr>
#     <tr>
#       <th>2dda7p_c</th>
#       <td>-467.9060</td>
#     </tr>
#     <tr>
#       <th>2ddecg3p_c</th>
#       <td>-348.7750</td>
#     </tr>
#     <tr>
#       <th>2ddg6p_c</th>
#       <td>-431.6070</td>
#     </tr>
#     <tr>
#       <th>2ddglcn_c</th>
#       <td>-222.2060</td>
#     </tr>
#     <tr>
#       <th>2dh3dgal_c</th>
#       <td>-219.7150</td>
#     </tr>
#     <tr>
#       <th>2dh3dgal6p_c</th>
#       <td>-431.6070</td>
#     </tr>
#     <tr>
#       <th>2dhguln_c</th>
#       <td>-257.6600</td>
#     </tr>
#     <tr>
#       <th>2dhp_c</th>
#       <td>-148.6590</td>
#     </tr>
#     <tr>
#       <th>2dmmq8_c</th>
#       <td>208.4720</td>
#     </tr>
#     <tr>
#       <th>2dmmql8_c</th>
#       <td>184.0690</td>
#     </tr>
#     <tr>
#       <th>2dr1p_c</th>
#       <td>-352.9020</td>
#     </tr>
#     <tr>
#       <th>2dr5p_c</th>
#       <td>-352.9030</td>
#     </tr>
#     <tr>
#       <th>2h3oppan_c</th>
#       <td>-149.8170</td>
#     </tr>
#     <tr>
#       <th>2hdec9eg3p_c</th>
#       <td>-319.8530</td>
#     </tr>
#     <tr>
#       <th>2hdecg3p_c</th>
#       <td>-342.1940</td>
#     </tr>
#     <tr>
#       <th>2ippm_c</th>
#       <td>-142.6780</td>
#     </tr>
#     <tr>
#       <th>2mahmp_c</th>
#       <td>-412.4040</td>
#     </tr>
#     <tr>
#       <th>2mcacn_c</th>
#       <td>-222.6120</td>
#     </tr>
#     <tr>
#       <th>2mcit_c</th>
#       <td>-280.4140</td>
#     </tr>
#     <tr>
#       <th>2me4p_c</th>
#       <td>-365.5040</td>
#     </tr>
#     <tr>
#       <th>2obut_c</th>
#       <td>-110.9280</td>
#     </tr>
#     <tr>
#       <th>2odec11eg3p_c</th>
#       <td>-316.5620</td>
#     </tr>
#     <tr>
#       <th>2odecg3p_c</th>
#       <td>-338.9040</td>
#     </tr>
#     <tr>
#       <th>2ohph_c</th>
#       <td>175.2550</td>
#     </tr>
#     <tr>
#       <th>2ombzl_c</th>
#       <td>150.7870</td>
#     </tr>
#     <tr>
#       <th>2omhmbl_c</th>
#       <td>109.7890</td>
#     </tr>
#     <tr>
#       <th>2ommbl_c</th>
#       <td>149.2050</td>
#     </tr>
#     <tr>
#       <th>2omph_c</th>
#       <td>190.2020</td>
#     </tr>
#     <tr>
#       <th>2oph_c</th>
#       <td>214.6710</td>
#     </tr>
#     <tr>
#       <th>2p4c2me_c</th>
#       <td>-856.9750</td>
#     </tr>
#     <tr>
#       <th>2pg_c</th>
#       <td>-371.1370</td>
#     </tr>
#     <tr>
#       <th>2pglyc_c</th>
#       <td>-334.8390</td>
#     </tr>
#     <tr>
#       <th>2shchc_c</th>
#       <td>-193.5190</td>
#     </tr>
#     <tr>
#       <th>2tdec7eg3p_c</th>
#       <td>-323.1440</td>
#     </tr>
#     <tr>
#       <th>2tdecg3p_c</th>
#       <td>-345.4850</td>
#     </tr>
#     <tr>
#       <th>2tpr3dpcoa_c</th>
#       <td>-1297.0800</td>
#     </tr>
#     <tr>
#       <th>34hpp_c</th>
#       <td>-114.8580</td>
#     </tr>
#     <tr>
#       <th>3c2hmp_c</th>
#       <td>-199.5390</td>
#     </tr>
#     <tr>
#       <th>3c3hmp_c</th>
#       <td>-199.5390</td>
#     </tr>
#     <tr>
#       <th>3c4mop_c</th>
#       <td>-189.0560</td>
#     </tr>
#     <tr>
#       <th>3dhguln_c</th>
#       <td>-260.1500</td>
#     </tr>
#     <tr>
#       <th>3dhgulnp_c</th>
#       <td>-472.0420</td>
#     </tr>
#     <tr>
#       <th>3dhq_c</th>
#       <td>-215.0630</td>
#     </tr>
#     <tr>
#       <th>3dhsk_c</th>
#       <td>-166.8340</td>
#     </tr>
#     <tr>
#       <th>3hbcoa_c</th>
#       <td>-819.2920</td>
#     </tr>
#     <tr>
#       <th>3hcinnm_c</th>
#       <td>-71.3229</td>
#     </tr>
#     <tr>
#       <th>3hdcoa_c</th>
#       <td>-809.4210</td>
#     </tr>
#     <tr>
#       <th>3hddcoa_c</th>
#       <td>-806.1300</td>
#     </tr>
#     <tr>
#       <th>3hhcoa_c</th>
#       <td>-816.0020</td>
#     </tr>
#     <tr>
#       <th>3hhdcoa_c</th>
#       <td>-799.5490</td>
#     </tr>
#     <tr>
#       <th>3hocoa_c</th>
#       <td>-812.7110</td>
#     </tr>
#     <tr>
#       <th>3hodcoa_c</th>
#       <td>-796.2580</td>
#     </tr>
#     <tr>
#       <th>3hpppn_c</th>
#       <td>-87.3972</td>
#     </tr>
#     <tr>
#       <th>3htdcoa_c</th>
#       <td>-802.8390</td>
#     </tr>
#     <tr>
#       <th>3ig3p_c</th>
#       <td>-267.2660</td>
#     </tr>
#     <tr>
#       <th>3mob_c</th>
#       <td>-111.0380</td>
#     </tr>
#     <tr>
#       <th>3mop_c</th>
#       <td>-109.3930</td>
#     </tr>
#     <tr>
#       <th>3odcoa_c</th>
#       <td>-801.4280</td>
#     </tr>
#     <tr>
#       <th>3oddcoa_c</th>
#       <td>-798.1370</td>
#     </tr>
#     <tr>
#       <th>3ohcoa_c</th>
#       <td>-808.0090</td>
#     </tr>
#     <tr>
#       <th>3ohdcoa_c</th>
#       <td>-791.5560</td>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-30d16049d151> in <module>()
#      23 display(HTML(mu0.to_frame().to_html()))
#      24
# ---> 25 idx = fullS.index.intersection(mu0.index)
#      26
#      27 deltaG0 = fullS.loc[idx].T.dot(mu0[idx])
#
# NameError: name 'fullS' is not defined

# %% [markdown]
# # Boltzmann (Model and Simulation )

# %% [markdown]
# ## Run Deterministic Simulation

# %%
cat PPP_Gly_TCA_A-COA-Bys1_concs_mod.in
# Out:
# VOLUME 1.0e-15
# CONC_UNITS 1.0e-0
# D-GLUCOPYRANOSE 2.00e-03        F
# D-GLUCOPYRANOSE_6-PHOSPHATE     2.00e-03        V
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE       1.00e-03        V
# FRUCTOSE_1,6-BISPHOSPHATE       5.399237e-04    V
# D-GLYCERALDEHYDE_3-PHOSPHATE    1.00e-03        V
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE 2.536071e-03    V
# GLYCERONE_PHOSPHATE     2.877076e-06       V
# 3-PHOSPHO-D-GLYCERATE   4.182558e-05    V
# 2-PHOSPHO-D-GLYCERATE   2.343639e-03 V
# PHOSPHOENOLPYRUVATE     1.00e-03        V
# PYRUVATE        1.00e-03        V
# ACETYL-COA      1.00e-05        V
# MALATE  1.00e-05        V
# OXALOACETATE    1.00e-03        V
# CITRATE         1.00e-05        V
# CIS-ACONITATE   1.00e-05        V
# D-THREO-ISOCITRATE      1.00e-05        V
# 2-OXOGLUTARATE  1.00e-05        V
# SUCCINYL-COA    1.00e-05        V
# GLYOXYLATE      1.00e-05        V
# SUCCINATE_SEMIALDEHYDE  1.00e-05        V
# SUCCINATE       1.00e-05        V
# FUMARATE        1.00e-05        V
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE         1.00e-05        V
# D-GLUCONATE_6-PHOSPHATE         1.00e-05        V
# D-RIBULOSE_5-PHOSPHATE  1.00e-05        V
# D-XYLULOSE_5-PHOSPHATE  2.320598e-06    F
# ALPHA-D-RIBOSE_5-PHOSPHATE      1.00e-05        V
# SEDOHEPTULOSE_7-PHOSPHATE       1.00e-05        V
# D-ERYTHROSE_4-PHOSPHATE         1.00e-05        V
# ORTHOPHOSPHATE  2.0e-02  F
# H2O     1.00e-0  	F
# CO2     1.00e-04        F
# COA     1.40e-03        F
# ATP     9.60e-03        F
# ADP     5.60e-04        F
# NAD+    2.60e-03        F
# NADH    8.30e-05        F
# NADP+   2.10e-06        F
# NADPH   1.20e-04        F
# AN_ELECTRON-TRANSFER_QUINONE    1.00e-03        F
# AN_ELECTRON-TRANSFER_QUINOL     1.00e-03        F

# %%
cat PPP_Gly_TCA_A-COA-Bys1_rxns_mod.dat
# Out:
# REACTION HEX1  :: GLUCOKIN-RXN
# LEFT    D-GLUCOPYRANOSE + ATP
# RIGHT   D-GLUCOPYRANOSE_6-PHOSPHATE + ADP
# DGZERO  -2.262219e+01
# //
# REACTION        PGI  :: PGLUCISOM-RXN
# LEFT    D-GLUCOPYRANOSE_6-PHOSPHATE
# RIGHT   BETA-D-FRUCTOFURANOSE_6-PHOSPHATE
# DGZERO  -2.268132e+00
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        PFKh  :: 6PFRUCTPHOS-RXN
# LEFT    ATP     +       BETA-D-FRUCTOFURANOSE_6-PHOSPHATE
# RIGHT         ADP     +       FRUCTOSE_1,6-BISPHOSPHATE
# DGZERO  -23.300000
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        BFBPh  :: F16BDEPHOS-RXN
# LEFT    FRUCTOSE_1,6-BISPHOSPHATE       +       H2O
# RIGHT   BETA-D-FRUCTOFURANOSE_6-PHOSPHATE       +       ORTHOPHOSPHATE
# DGZERO  6.8935547
# ENZYME_LEVEL    0.0
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        FBAF  :: F16ALDOLASE-RXN
# LEFT    FRUCTOSE_1,6-BISPHOSPHATE
# RIGHT   GLYCERONE_PHOSPHATE     +       D-GLYCERALDEHYDE_3-PHOSPHATE
# DGZERO  2.215230e+01
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        TPI  :: TRIOSEPISOMERIZATION-RXN
# LEFT   GLYCERONE_PHOSPHATE
# RIGHT    D-GLYCERALDEHYDE_3-PHOSPHATE
# DGZERO  7.660000e+00
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        G6PIh  :: GAPOXNPHOSPHN-RXN
# LEFT    D-GLYCERALDEHYDE_3-PHOSPHATE    +       ORTHOPHOSPHATE  +       NAD+
# RIGHT         3-PHOSPHO-D-GLYCEROYL_PHOSPHATE +       NADH
# DGZERO  2.299890e+00
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        PGKm  :: PHOSGLYPHOS-RXN
# LEFT    3-PHOSPHO-D-GLYCEROYL_PHOSPHATE +       ADP
# RIGHT   3-PHOSPHO-D-GLYCERATE   +       ATP
# DGZERO  -8.139283e+00
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        PGM  :: RXN-15513
# LEFT    3-PHOSPHO-D-GLYCERATE
# RIGHT   2-PHOSPHO-D-GLYCERATE
# DGZERO  5.897848e+00
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        ENOf  :: 2PGADEHYDRAT-RXN
# LEFT    2-PHOSPHO-D-GLYCERATE
# RIGHT   PHOSPHOENOLPYRUVATE     +       H2O
# DGZERO  -3.412649e+00
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        PYKf :: PEPDEPHOS-RXN
# LEFT       PHOSPHOENOLPYRUVATE     +       ADP
# RIGHT   PYRUVATE        +       ATP
# DGZERO  -2.234192
# DGZERO_UNITS    KJ/MOL
# PATHWAY PPP
# //
# REACTION    PDHm  :: PYRUVDEH-RXN
# LEFT    COA + NAD+ + PYRUVATE
# RIGHT   ACETYL-COA + CO2 + NADH
# DGZERO  -2.482891e+01
# DGZERO_UNITS    KJ/MOL
# COMMENT COMMENT PYRUVATE DEHYDROGENASE SUMMARY Rxn from neurospora model
# PATHWAY pyruvate dehydrogenase
# //
# REACTION      CS  :: CITSYN-RXN
# LEFT    ACETYL-COA      +       H2O     +       OXALOACETATE
# RIGHT   CITRATE +       COA
# DGZERO  -4.410008e+01
# DGZERO_UNITS    KJ/MOL
# PATHWAY ACETYL-COA to TCA
# //
# REACTION        ACONTa  :: ACONITATEDEHYDR-RXN
# LEFT    CITRATE
# RIGHT   CIS-ACONITATE   +       H2O
# DGZERO  3.3529968
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        ACONITATEHYDR__RXN :: ACONITATEHYDR-RXN
# LEFT    CIS-ACONITATE   +       H2O
# RIGHT   D-THREO-ISOCITRATE
# DGZERO  8.3
# DGZERO_UNITS    KJ/MOL
# //
# REACTION	ICDHxm  :: ISOCITRATE-DEHYDROGENASE-NAD+-RXN
# LEFT    D-THREO-ISOCITRATE      +       NAD+
# RIGHT   2-OXOGLUTARATE  +       CO2     +       NADH
# DGZERO  7.830200e-01
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        ISOCIT__CLEAV__RXN :: ISOCIT-CLEAV-RXN
# LEFT    D-THREO-ISOCITRATE
# RIGHT   GLYOXYLATE      +       SUCCINATE
# DGZERO  3.2682343
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        MALSp  :: MALSYN-RXN
# LEFT    ACETYL-COA      +       H2O     +       GLYOXYLATE
# RIGHT   MALATE  +       COA
# DGZERO  -4.727124e+01
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        OXGDC  :: RXN-7774
# LEFT            2-OXOGLUTARATE
# RIGHT   SUCCINATE_SEMIALDEHYDE  +       CO2
# DGZERO  -2.1417694
# DGZERO_UNITS    KJ/MOL
# //
# REACTION       AKGDm  :: 2OXOGLUTARATEDEH-RXN
# LEFT    2-OXOGLUTARATE  +       COA     +       NAD+
# RIGHT   SUCCINYL-COA    +       CO2     +       NADH
# DGZERO  -3.165345e+01
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        SUCOAS  :: SUCCCOASYN-RXN
# LEFT    SUCCINYL-COA    +       ADP     +       ORTHOPHOSPHATE
# RIGHT   SUCCINATE       +       COA     +       ATP
# DGZERO  1.995839e+00
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        SUCD1m  :: RXN-14971
# LEFT    AN_ELECTRON-TRANSFER_QUINONE    +       SUCCINATE
# RIGHT   AN_ELECTRON-TRANSFER_QUINOL     +       FUMARATE
# DGZERO  0.000000e+00
# DGZERO_UNITS    KJ/MOL
#
# REACTION        FUMm  :: FUMHYDR-RXN
# LEFT    FUMARATE        +       H2O
# RIGHT   MALATE
# DGZERO  -3.611371e+00
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        MDHm :: MALATE-DEH-RXN
# LEFT    MALATE  +       NAD+
# RIGHT   OXALOACETATE    +       NADH
# DGZERO  2.929091e+01
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        G6PDH2r  :: GLU6PDEHYDROG-RXN
# LEFT    D-GLUCOPYRANOSE_6-PHOSPHATE     +       NADP+
# RIGHT   6-PHOSPHO_D-GLUCONO-1,5-LACTONE +       NADPH
# DGZERO  -1.369839e+00
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY  PPP
# //
# REACTION       PGLh  :: 6PGLUCONOLACT-RXN
# LEFT    6-PHOSPHO_D-GLUCONO-1,5-LACTONE +       H2O
# RIGHT           D-GLUCONATE_6-PHOSPHATE
# DGZERO  -7.355438
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY PPP
# //
# REACTION        PGDHh  :: RXN-9952
# LEFT    D-GLUCONATE_6-PHOSPHATE +       NADP+
# RIGHT   D-RIBULOSE_5-PHOSPHATE  +       CO2     +       NADPH
# DGZERO  -1.3841553
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY PPP
# //
# REACTION        RPEh  :: RIBULP3EPIM-RXN
# LEFT    D-RIBULOSE_5-PHOSPHATE
# RIGHT   D-XYLULOSE_5-PHOSPHATE
# DGZERO  -00.00000
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY PPP
# //
# REACTION        RPI :: RIB5PISOM-RXN
# RIGHT   D-RIBULOSE_5-PHOSPHATE
# LEFT    ALPHA-D-RIBOSE_5-PHOSPHATE
# DGZERO  0.46000
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY CALVIN CYCLE, PENTOSE PHOSPHATE PATHWAY, RUBISCO SHUNT
# //
# REACTION        TKT1 :: 1TRANSKETO-RXN
# LEFT    SEDOHEPTULOSE_7-PHOSPHATE       +       D-GLYCERALDEHYDE_3-PHOSPHATE
# RIGHT   ALPHA-D-RIBOSE_5-PHOSPHATE      +       D-XYLULOSE_5-PHOSPHATE
# DGZERO  -0.1821793
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY CALVIN CYCLE, PENTOSE PHOSPHATE PATHWAY, RUBISCO SHUNT
# //
# REACTION        TALA  :: TRANSALDOL-RXN
# LEFT    SEDOHEPTULOSE_7-PHOSPHATE       +       D-GLYCERALDEHYDE_3-PHOSPHATE
# RIGHT   BETA-D-FRUCTOFURANOSE_6-PHOSPHATE       +       D-ERYTHROSE_4-PHOSPHATE
# DGZERO  -8.640509
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY RUBISCO SHUNT, PENTOSE PHOSPHATE PATHWAY
# COMMENT From Equilibrator pH 7.5 IS 0.15
# //
# REACTION        TKT2 :: 2TRANSKETO-RXN
# LEFT    D-ERYTHROSE_4-PHOSPHATE +       D-XYLULOSE_5-PHOSPHATE
# RIGHT   BETA-D-FRUCTOFURANOSE_6-PHOSPHATE       +       D-GLYCERALDEHYDE_3-PHOSPHATE
# DGZERO  4.697130
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY CALVIN CYCLE, PENTOSE PHOSPHATE PATHWAY, RUBISCO SHUNT
# COMMENT From Equilibrator pH 7.5, IS 0.15
# //

# %%
cat PPP_Gly_TCA_A-COA-Bys1_concs_mod.in
# Out:
# VOLUME 1.0e-15
# CONC_UNITS 1.0e-0
# D-GLUCOPYRANOSE 2.00e-03        F
# D-GLUCOPYRANOSE_6-PHOSPHATE     2.00e-03        V
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE       1.00e-03        V
# FRUCTOSE_1,6-BISPHOSPHATE       5.399237e-04    V
# D-GLYCERALDEHYDE_3-PHOSPHATE    1.00e-03        V
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE 2.536071e-03    V
# GLYCERONE_PHOSPHATE     2.877076e-06       V
# 3-PHOSPHO-D-GLYCERATE   4.182558e-05    V
# 2-PHOSPHO-D-GLYCERATE   2.343639e-03 V
# PHOSPHOENOLPYRUVATE     1.00e-03        V
# PYRUVATE        1.00e-03        V
# ACETYL-COA      1.00e-05        V
# MALATE  1.00e-05        V
# OXALOACETATE    1.00e-03        V
# CITRATE         1.00e-05        V
# CIS-ACONITATE   1.00e-05        V
# D-THREO-ISOCITRATE      1.00e-05        V
# 2-OXOGLUTARATE  1.00e-05        V
# SUCCINYL-COA    1.00e-05        V
# GLYOXYLATE      1.00e-05        V
# SUCCINATE_SEMIALDEHYDE  1.00e-05        V
# SUCCINATE       1.00e-05        V
# FUMARATE        1.00e-05        V
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE         1.00e-05        V
# D-GLUCONATE_6-PHOSPHATE         1.00e-05        V
# D-RIBULOSE_5-PHOSPHATE  1.00e-05        V
# D-XYLULOSE_5-PHOSPHATE  2.320598e-06    F
# ALPHA-D-RIBOSE_5-PHOSPHATE      1.00e-05        V
# SEDOHEPTULOSE_7-PHOSPHATE       1.00e-05        V
# D-ERYTHROSE_4-PHOSPHATE         1.00e-05        V
# ORTHOPHOSPHATE  2.0e-02  F
# H2O     1.00e-0  	F
# CO2     1.00e-04        F
# COA     1.40e-03        F
# ATP     9.60e-03        F
# ADP     5.60e-04        F
# NAD+    2.60e-03        F
# NADH    8.30e-05        F
# NADP+   2.10e-06        F
# NADPH   1.20e-04        F
# AN_ELECTRON-TRANSFER_QUINONE    1.00e-03        F
# AN_ELECTRON-TRANSFER_QUINOL     1.00e-03        F

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import subprocess
import re
import os
from IPython.core.display import display
pd.set_option('display.max_columns', None,'display.max_rows', None)

#args = ("/Users/kuma889/Projects/Boltzmann/Boltz/05_boltz_bug_fix_4432/boltzmann", "central_metabolism_dg0.in")

popen = subprocess.Popen(args, stdout=subprocess.PIPE)
popen.wait()
output = popen.stdout.read()
print(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-26314c68f544> in <module>()
#      11 #args = ("/Users/kuma889/Projects/Boltzmann/Boltz/05_boltz_bug_fix_4432/boltzmann", "central_metabolism_dg0.in")
#      12
# ---> 13 popen = subprocess.Popen(args, stdout=subprocess.PIPE)
#      14 popen.wait()
#      15 output = popen.stdout.read()
#
# NameError: name 'args' is not defined

# %% [markdown]
# ## Analyze Simulation Results for centeral Metabolism of O. tuari

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import subprocess
import re
import os
from IPython.core.display import display
#from ipynb_latex_setup import *
# %matplotlib inline
N_avogadro = 6.022140857e+23
VolCell = 1.0e-15
Concentration2Count = N_avogadro * VolCell
concentration_increment = 1/(N_avogadro*VolCell)
RT = 8.3144598e-03 * 298.15

# %% [markdown]
#  ### Derivatives from ODE thermodynamic optimization simulation

# %%
# Read boltzmann stochastic reaction likelihoods
ode_derivatives = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_dconcs',header=0,index_col=0)
abs_derivatives = np.abs(ode_derivatives.iloc[-1,:])
display(abs_derivatives.sort_values())
plt.figure();ode_derivatives.plot(legend=False,logx=False,logy=False,figsize=(10, 10))
plt.yscale('symlog')
#ode_derivatives = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.rstrt',header=None,index_col=0,skiprows=2)
#column_names = [x.split(":")[0] for x in ode_metabolites.columns]
#column_names = [x.split(":")[0] for x in ode_metabolites.columns]
#ode_metabolites.columns = column_namesode_derivatives = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_dconcs',header=0,index_col=0)
# Get the absolute value of the derivatives:

#plt.figure();ode_derivatives.iloc[-5000:-1500,:].plot(legend=False,logx=True,logy=False,figsize=(10, 10))

#plt.legend(bbox_to_anchor=(1.35, 1.05),bbox_transform=plt.gcf().transFigure)
# Out:
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# D-GLYCERALDEHYDE_3-PHOSPHATE:         0.000000e+00
# GLYCERONE_PHOSPHATE:                  0.000000e+00
# FUMARATE:                             0.000000e+00
# NADP+:                                0.000000e+00
# D-XYLULOSE_5-PHOSPHATE:               0.000000e+00
# D-RIBULOSE_5-PHOSPHATE:               0.000000e+00
# SUCCINATE_SEMIALDEHYDE:               0.000000e+00
# NADPH:                                0.000000e+00
# D-GLUCOPYRANOSE:                      0.000000e+00
# D-GLUCONATE_6-PHOSPHATE:              0.000000e+00
# D-ERYTHROSE_4-PHOSPHATE:              0.000000e+00
# COA:                                  0.000000e+00
# NADH:                                 0.000000e+00
# CO2:                                  0.000000e+00
# CIS-ACONITATE:                        0.000000e+00
# ATP:                                  0.000000e+00
# AN_ELECTRON-TRANSFER_QUINONE:         0.000000e+00
# AN_ELECTRON-TRANSFER_QUINOL:          0.000000e+00
# ALPHA-D-RIBOSE_5-PHOSPHATE:           0.000000e+00
# ADP:                                  0.000000e+00
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE:      0.000000e+00
# SEDOHEPTULOSE_7-PHOSPHATE:            0.000000e+00
# ORTHOPHOSPHATE:                       0.000000e+00
# NAD+:                                 0.000000e+00
# GLYOXYLATE:                           1.214306e-17
# D-THREO-ISOCITRATE:                   4.440892e-16
# ACETYL-COA:                           4.562323e-16
# PHOSPHOENOLPYRUVATE:                  8.881784e-16
# PYRUVATE:                             8.881784e-16
# SUCCINATE:                            8.881784e-16
# 2-OXOGLUTARATE:                       8.881784e-16
# 2-PHOSPHO-D-GLYCERATE:                8.881784e-16
# MALATE:                               8.881784e-16
# OXALOACETATE:                         1.776357e-15
# SUCCINYL-COA:                         1.776357e-15
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE:    8.437695e-15
# D-GLUCOPYRANOSE_6-PHOSPHATE:          1.865175e-14
# 3-PHOSPHO-D-GLYCERATE:                3.552714e-14
# CITRATE:                              3.819167e-14
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE:      1.572076e-13
# FRUCTOSE_1,6-BISPHOSPHATE:            6.585430e-10
# Name: 99999980.0, dtype: float64

# %% [markdown]
# The values reported are those obtained just before the solver became unstable, at relative time 999974.8.

# %%
display(ode_derivatives.loc[99999980].sort_values())
# Out:
# 2-OXOGLUTARATE:                      -8.881784e-16
# 2-PHOSPHO-D-GLYCERATE:               -8.881784e-16
# SUCCINATE:                           -8.881784e-16
# PHOSPHOENOLPYRUVATE:                 -8.881784e-16
# MALATE:                              -8.881784e-16
# D-THREO-ISOCITRATE:                  -4.440892e-16
# D-RIBULOSE_5-PHOSPHATE:               0.000000e+00
# D-XYLULOSE_5-PHOSPHATE:               0.000000e+00
# FUMARATE:                             0.000000e+00
# GLYCERONE_PHOSPHATE:                  0.000000e+00
# NADH:                                 0.000000e+00
# SUCCINATE_SEMIALDEHYDE:               0.000000e+00
# NADP+:                                0.000000e+00
# NADPH:                                0.000000e+00
# ORTHOPHOSPHATE:                       0.000000e+00
# SEDOHEPTULOSE_7-PHOSPHATE:            0.000000e+00
# NAD+:                                 0.000000e+00
# D-GLUCOPYRANOSE:                      0.000000e+00
# D-GLYCERALDEHYDE_3-PHOSPHATE:         0.000000e+00
# AN_ELECTRON-TRANSFER_QUINONE:         0.000000e+00
# D-ERYTHROSE_4-PHOSPHATE:              0.000000e+00
# COA:                                  0.000000e+00
# CO2:                                  0.000000e+00
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE:      0.000000e+00
# CIS-ACONITATE:                        0.000000e+00
# ATP:                                  0.000000e+00
# D-GLUCONATE_6-PHOSPHATE:              0.000000e+00
# AN_ELECTRON-TRANSFER_QUINOL:          0.000000e+00
# ALPHA-D-RIBOSE_5-PHOSPHATE:           0.000000e+00
# ADP:                                  0.000000e+00
# GLYOXYLATE:                           1.214306e-17
# ACETYL-COA:                           4.562323e-16
# PYRUVATE:                             8.881784e-16
# OXALOACETATE:                         1.776357e-15
# SUCCINYL-COA:                         1.776357e-15
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE:    8.437695e-15
# D-GLUCOPYRANOSE_6-PHOSPHATE:          1.865175e-14
# 3-PHOSPHO-D-GLYCERATE:                3.552714e-14
# CITRATE:                              3.819167e-14
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE:      1.572076e-13
# FRUCTOSE_1,6-BISPHOSPHATE:            6.585430e-10
# Name: 99999980.0, dtype: float64

# %% [markdown]
# ### Likelihoods from Deterministic Simulation

# %%
# Read boltzmann ODE reaction likelihoods
columns = np.arange(1,52,1)
fwd_column_idx = [x for x in np.arange(0,52,2)]
rev_column_idx = [x for x in np.arange(1,52,2)]
#rev_columns = np.arange(0,55,2)
ode_likelihoods_timeseries = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd',header=1, index_col = 0, quoting=2)
ode_fwd_likelihoods_timeseries = ode_likelihoods_timeseries.iloc[:,fwd_column_idx]
ode_rev_likelihoods_timeseries = ode_likelihoods_timeseries.iloc[:,rev_column_idx]

ode_fwd_likelihoods_timeseries.columns = [x.split("f_")[-1] for x in ode_fwd_likelihoods_timeseries.columns]
ode_rev_likelihoods_timeseries.columns = [x.split("r_")[-1] for x in ode_rev_likelihoods_timeseries.columns]
fwd_column = ode_likelihoods_timeseries.iloc[:,fwd_column_idx].columns
rev_column = ode_likelihoods_timeseries.iloc[:,rev_column_idx].columns
#column_names = [x.split("f_")[-1] for x in ode_likelihoods.columns]
#ode_likelihoods.columns = column_names

#plt.figure()
#ode_likelihoods.iloc[:,rev_column_idx].plot(legend=True,logx=True,figsize=(12, 12))
ode_fwd_likelihoods_timeseries.plot(legend=True,logx=False,figsize=(9, 9))
plt.yscale('symlog')
plt.legend(bbox_to_anchor=(1.25, 0.75),bbox_transform=plt.gcf().transFigure)
np.log10(ode_fwd_likelihoods_timeseries.iloc[-100:]).mean()
# Out:
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/ipykernel/__main__.py:22: RuntimeWarning: divide by zero encountered in log10
# HEX1                  0.602995
# PGI                   0.602995
# PFKh                  0.602995
# BFBPh                     -inf
# FBAF                  0.602994
# TPI                   0.602994
# G6PIh                 0.883607
# PGKm                  0.883608
# PGM                   0.883608
# ENOf                  0.876129
# PYKf                  0.876121
# PDHm                  0.876121
# CS                    0.876121
# ACONTa                0.876174
# ACONITATEHYDR__RXN    0.876174
# ICDHxm                0.876121
# ISOCIT__CLEAV__RXN   -0.007701
# MALSp                -2.455079
# OXGDC                -7.988416
# AKGDm                 0.876121
# SUCOAS                0.883390
# FUMm                  0.883397
# MDHm                  0.883607
# G6PDH2r                   -inf
# PGLh                      -inf
# PGDHh                     -inf
# dtype: float64

# %% [markdown]
# ode_likelihoods_steadystate = pd.DataFrame(data = ode_fwd_likelihoods_timeseries.iloc[-20:].mean(),
#                                            index = ode_fwd_likelihoods_timeseries.columns,
#                                           columns =['Forward'])
# ode_likelihoods_steadystate['Reverse'] = ode_rev_likelihoods_timeseries.iloc[-20:].mean()
# ode_likelihoods_steadystate['For-Rev'] = ode_likelihoods_steadystate['Forward'] - ode_likelihoods_steadystate['Reverse']
# ode_likelihoods_steadystate['Rxn Probabilities'] = ode_likelihoods_steadystate['For-Rev']/np.sum(abs(ode_likelihoods_steadystate['For-Rev']))
# ode_likelihoods_steadystate

# %%
ode_likelihoods_steadystate = pd.DataFrame(data = ode_fwd_likelihoods_timeseries.iloc[-100:].mean(), 
                                           index = ode_fwd_likelihoods_timeseries.columns,
                                          columns =['Forward'])

ode_likelihoods_steadystate['Reverse'] = ode_rev_likelihoods_timeseries.iloc[-100:].mean()
ode_likelihoods_steadystate['For-Rev'] = ode_likelihoods_steadystate['Forward'] - ode_likelihoods_steadystate['Reverse']
ode_likelihoods_steadystate['Rxn Probabilities'] = ode_likelihoods_steadystate['For-Rev']/np.sum(abs(ode_likelihoods_steadystate['For-Rev']))
ode_likelihoods_steadystate
# Out:
#                          Forward       Reverse   For-Rev  Rxn Probabilities
# HEX1                4.008620e+00  2.494614e-01  3.759159           0.030303
# PGI                 4.008621e+00  2.494624e-01  3.759159           0.030303
# PFKh                4.008620e+00  2.494616e-01  3.759158           0.030303
# BFBPh               0.000000e+00  0.000000e+00  0.000000           0.000000
# FBAF                4.008611e+00  2.494524e-01  3.759159           0.030303
# TPI                 4.008611e+00  2.494524e-01  3.759159           0.030303
# G6PIh               7.649044e+00  1.307271e-01  7.518317           0.060606
# PGKm                7.649051e+00  1.307348e-01  7.518316           0.060606
# PGM                 7.649052e+00  1.307352e-01  7.518317           0.060606
# ENOf                7.518454e+00  1.376224e-04  7.518316           0.060606
# PYKf                7.518317e+00  1.053743e-10  7.518317           0.060606
# PDHm                7.518317e+00  1.260603e-12  7.518317           0.060606
# CS                  7.518318e+00  1.646477e-06  7.518316           0.060606
# ACONTa              7.519247e+00  9.302402e-04  7.518317           0.060606
# ACONITATEHYDR__RXN  7.519247e+00  9.301932e-04  7.518317           0.060606
# ICDHxm              7.518321e+00  4.683615e-06  7.518316           0.060606
# ISOCIT__CLEAV__RXN  9.824241e-01  9.824241e-01  0.000000           0.000000
# MALSp               3.506881e-03  3.506881e-03  0.000000           0.000000
# OXGDC               1.027031e-08  1.027031e-08  0.000000           0.000000
# AKGDm               7.518321e+00  4.677357e-06  7.518316           0.060606
# SUCOAS              7.645216e+00  1.268997e-01  7.518316           0.060606
# FUMm                7.645348e+00  1.270315e-01  7.518317           0.060606
# MDHm                7.649049e+00  1.307324e-01  7.518317           0.060606
# G6PDH2r             0.000000e+00  0.000000e+00  0.000000           0.000000
# PGLh                0.000000e+00  0.000000e+00  0.000000           0.000000
# PGDHh               0.000000e+00  0.000000e+00  0.000000           0.000000

# %%
concs = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_concs',index_col=0)#.apply(np.log)
log_concs = concs.apply(np.log).T
log_concs.index
mets = {'2-PHOSPHO-D-GLYCERATE':'2-PG', 
        '3-PHOSPHO-D-GLYCERATE':'G3P',
        '3-PHOSPHO-D-GLYCEROYL_PHOSPHATE':'DPG', 
        'ADP':'ADP', 
        'AMP':'AMP', 
        'ATP':'ATP',
       'BETA-D-FRUCTOFURANOSE_6-PHOSPHATE':'FRUCTOSE-6P', 
        'D-GLUCOPYRANOSE_6-PHOSPHATE':'D-glucopyranose-6-phosphate',
       'D-GLYCERALDEHYDE_3-PHOSPHATE':'GAP', 
        'FRUCTOSE_1,6-BISPHOSPHATE':'FRUCTOSE-16-DIPHOSPHATE',
       'GLYCERONE_PHOSPHATE':'DIHYDROXY-ACETONE-PHOSPHATE', 
        'H+':'PROTON', 
        'NAD+':'NAD', 
        'NADH':'NADH', 
        'ORTHOPHOSPHATE':'Pi',
       'PHOSPHOENOLPYRUVATE':'PHOSPHO-ENOL-PYRUVATE', 
        'PYRUVATE':'PYRUVATE'}

log_concs.index = [mets[m] for m in log_concs.index]
log_concs.index.name='$Metabolite'

log_concs.to_csv('central_metabolism_dg0_rxns_GLy.log_concs.tab',sep='\t')
#og_concs
# Out:
# ---------------------------------------------------------------------
# KeyError                            Traceback (most recent call last)
# <ipython-input-232-eaff86b9b991> in <module>()
#      20         'PYRUVATE':'PYRUVATE'}
#      21
# ---> 22 log_concs.index = [mets[m] for m in log_concs.index]
#      23 log_concs.index.name='$Metabolite'
#      24
#
# KeyError: '2-OXOGLUTARATE'

# %%
import pandas as pd
import numpy as np
import re, os
def to_chr(  matchobj ):
        return chr(int(matchobj.group(1)))
def to_ord( matchobj ):
        return '__{}__'.format(ord(matchobj.group(0)))    
def munge( sbmlid ):
    alphaRE = re.compile(r'[^A-Za-z_]')
    m = alphaRE.match(sbmlid[0])
    if m:
        sbmlid = '_{}'.format(sbmlid)
    alphanumRE = re.compile(r'[^A-Za-z0-9_]')
    sbmlid = alphanumRE.sub(to_ord, sbmlid)
    return sbmlid
def unmunge( sbmlid ):
    ordRE = re.compile('__([0-9]+)__')
    if '_' == sbmlid[0] and '_' != sbmlid[1]:
        sbmlid = sbmlid[1:]
    return ordRE.sub( to_chr, sbmlid)    
def unmunge_model( model ):     
    for met in model.metabolites:
        met.id = unmunge(met.id)
    for rxn in model.reactions:
        rxn.id = unmunge(rxn.id)
    return model

# %%
likelihoods = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd',skiprows=1).T
likelihoods.iloc[3:]
forward_likelihoods = likelihoods.iloc[3::2]
idx = [unmunge(rxn[2:]) for rxn in forward_likelihoods.index]
forward_likelihoods.index = idx
display(forward_likelihoods)

backward_likelihoods = likelihoods.iloc[4::2]
backward_likelihoods.index = idx
display(backward_likelihoods)

net_likelihoods = ode_likelihoods_steadystate['Forward'] - ode_likelihoods_steadystate['Reverse']
net_likelihoods.index.name = '$FrameId'
display(net_likelihoods)

net_likelihoods.columns = [str(c) for c in net_likelihoods.columns]
net_likelihoods.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_net_likelihood.tab', sep='\t')

ode_likelihoods_steadystate.columns = [str(c) for c in ode_likelihoods_steadystate['For-Rev'].columns]
ode_likelihoods_steadystate['For-Rev'].to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_likelihood.tab', sep='\t')

# %%
net_likelihoods.index.name = '$FrameId'
display(net_likelihoods)

net_likelihoods.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd_net_likel.tab',sep='\t')
ode_likelihoods_steadystate.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd_net_stead.tab', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4c368e4a2e23> in <module>()
# ----> 1 net_likelihoods.index.name = '$FrameId'
#       2 display(net_likelihoods)
#       3
#       4 net_likelihoods.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd_net_likel.tab',sep='\t')
#       5 ode_likelihoods_steadystate.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd_net_stead.tab', sep='\t')
#
# NameError: name 'net_likelihoods' is not defined

# %% [markdown]
# ### Conversion from BiGG ids to Biocyc

# %%
with open('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.dat') as rxnfile:
    rxnmaps = {}
    for line in rxnfile:
        if 'REACTION' in line:
            rxn_tokens = [token.strip() for token in line.split()]
            rxnmaps[rxn_tokens[1]] = rxn_tokens[3]
print(rxnmaps)
net_likelihoods = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd_net_likel.tab',header=None, index_col=0, names=['Likelihood'])
net_likelihoods['$FrameId'] = pd.Series(rxnmaps, index=rxnmaps.keys())

net_likelihoods = net_likelihoods.reset_index().set_index('$FrameId')
#net_likelihoods = net_likelihoods.set_index('$FrameId')

net_likelihoods.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.biocyc',sep='\t')
net_likelihoods
# Out:
# {'G6PDH2r': 'GLU6PDEHYDROG-RXN', 'ENOf': '2PGADEHYDRAT-RXN', 'RPEh': 'RIBULP3EPIM-RXN', 'PDHm': 'PYRUVDEH-RXN', 'PFKh': '6PFRUCTPHOS-RXN', 'HEX1': 'GLUCOKIN-RXN', 'PGI': 'PGLUCISOM-RXN', 'ICDHxm': 'ISOCITRATE-DEHYDROGENASE-NAD+-RXN', 'FUMm': 'FUMHYDR-RXN', 'OXGDC': 'RXN-7774', 'AKGDm': '2OXOGLUTARATEDEH-RXN', 'PGM': 'RXN-15513', 'SUCD1m': 'RXN-14971', 'BFBPh': 'F16BDEPHOS-RXN', 'PYKf': 'PEPDEPHOS-RXN', 'RPI': 'RIB5PISOM-RXN', 'TALA': 'TRANSALDOL-RXN', 'SUCOAS': 'SUCCCOASYN-RXN', 'MDHm': 'MALATE-DEH-RXN', 'G6PIh': 'GAPOXNPHOSPHN-RXN', 'TPI': 'TRIOSEPISOMERIZATION-RXN', 'ACONTa': 'ACONITATEDEHYDR-RXN', 'FBAF': 'F16ALDOLASE-RXN', 'MALSp': 'MALSYN-RXN', 'PGLh': '6PGLUCONOLACT-RXN', 'CS': 'CITSYN-RXN', 'PGKm': 'PHOSGLYPHOS-RXN', 'TKT2': '2TRANSKETO-RXN', 'TKT1': '1TRANSKETO-RXN', 'PGDHh': 'RXN-9952', 'ACONITATEHYDR__RXN': 'ACONITATEHYDR-RXN', 'ISOCIT__CLEAV__RXN': 'ISOCIT-CLEAV-RXN'}
#                                                 index  Likelihood
# $FrameId
# GLUCOKIN-RXN                                     HEX1    3.759159
# PGLUCISOM-RXN                                     PGI    3.759159
# 6PFRUCTPHOS-RXN                                  PFKh    3.759158
# F16BDEPHOS-RXN                                  BFBPh    0.000000
# F16ALDOLASE-RXN                                  FBAF    3.759159
# TRIOSEPISOMERIZATION-RXN                          TPI    3.759159
# GAPOXNPHOSPHN-RXN                               G6PIh    7.518317
# PHOSGLYPHOS-RXN                                  PGKm    7.518316
# RXN-15513                                         PGM    7.518317
# 2PGADEHYDRAT-RXN                                 ENOf    7.518316
# PEPDEPHOS-RXN                                    PYKf    7.518317
# PYRUVDEH-RXN                                     PDHm    7.518317
# CITSYN-RXN                                         CS    7.518316
# ACONITATEDEHYDR-RXN                            ACONTa    7.518317
# ACONITATEHYDR-RXN                  ACONITATEHYDR__RXN    7.518317
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN              ICDHxm    7.518316
# ISOCIT-CLEAV-RXN                   ISOCIT__CLEAV__RXN    0.000000
# MALSYN-RXN                                      MALSp    0.000000
# RXN-7774                                        OXGDC    0.000000
# 2OXOGLUTARATEDEH-RXN                            AKGDm    7.518316
# SUCCCOASYN-RXN                                 SUCOAS    7.518316
# FUMHYDR-RXN                                      FUMm    7.518317
# MALATE-DEH-RXN                                   MDHm    7.518317
# GLU6PDEHYDROG-RXN                             G6PDH2r    0.000000
# 6PGLUCONOLACT-RXN                                PGLh    0.000000
# RXN-9952                                        PGDHh    0.000000

# %% [markdown]
# ## Analyze Metabolite Levels from Deterministic Simulation

# %%
# Read boltzmann stochastic reaction likelihoods
ode_metabolites = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_concs',header=0,index_col=0)
column_names = [x.split(":")[0] for x in ode_metabolites.columns]
ode_metabolites.columns = column_names

plt.figure();ode_metabolites.plot(legend=True,logy=True,figsize=(9, 9))
plt.legend(bbox_to_anchor=(1.34, 0.75),bbox_transform=plt.gcf().transFigure)

# %%
ode_metabolites_steadystate= \
  pd.DataFrame(data = ode_metabolites.iloc[-20:,:].mean(),columns=['ODE'])
ODE_met = ode_metabolites_steadystate.sort_values(by=['ODE'])
ODE_met.to_csv('PPP_Gly_TCA_A-COA-Bys1_Steadymets.biocyc',sep='\t')
#ode_likelihoods_steadystate.to_csv('PPP_Gly_TCA_A-COA-Bys1_Steadymets.biocyc',sep='\t')

# %%
fig = plt.figure();
plot = ode_metabolites[variable_metabolite_idx].plot(legend=False,logy=True,logx=True,figsize=(10, 10))
fig = plot.get_figure()
fig.savefig('metabolites_no_regulation.png')
plt.legend(bbox_to_anchor=(1.40, 0.90),bbox_transform=plt.gcf().transFigure)
fig.savefig('metabolites_no_regulation_legend.png',bbox_inches='tight')

# %%
ode_metabolites.iloc[-30:].mean()
#ode_metabolites['CO2']
# Out:
# 2-OXOGLUTARATE                       5.847891e-14
# 2-PHOSPHO-D-GLYCERATE                1.899655e+00
# 3-PHOSPHO-D-GLYCERATE                1.568910e+02
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE      7.713808e+02
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE      1.000000e-05
# ACETYL-COA                           2.055541e-14
# ADP                                  5.600000e-04
# ALPHA-D-RIBOSE_5-PHOSPHATE           1.000000e-05
# AN_ELECTRON-TRANSFER_QUINOL          1.000000e-03
# AN_ELECTRON-TRANSFER_QUINONE         1.000000e-03
# ATP                                  9.600000e-03
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE    4.897343e+01
# CIS-ACONITATE                        1.169665e-11
# CITRATE                              2.318089e+02
# CO2                                  1.000000e-04
# COA                                  1.400000e-03
# D-ERYTHROSE_4-PHOSPHATE              1.000000e-05
# D-GLUCONATE_6-PHOSPHATE              1.000000e-05
# D-GLUCOPYRANOSE                      2.000000e-03
# D-GLUCOPYRANOSE_6-PHOSPHATE          7.862738e+01
# D-GLYCERALDEHYDE_3-PHOSPHATE         3.955022e-05
# D-RIBULOSE_5-PHOSPHATE               1.000000e-05
# D-THREO-ISOCITRATE                   3.291877e-05
# D-XYLULOSE_5-PHOSPHATE               2.320598e-06
# FRUCTOSE_1,6-BISPHOSPHATE            2.530801e+06
# FUMARATE                             1.000000e-05
# GLYCERONE_PHOSPHATE                  3.485055e-03
# GLYOXYLATE                           2.536081e-07
# MALATE                               1.915357e+01
# NAD+                                 2.600000e-03
# NADH                                 8.300000e-05
# NADP+                                2.100000e-06
# NADPH                                1.200000e-04
# ORTHOPHOSPHATE                       2.000000e-02
# OXALOACETATE                         3.700555e-03
# PHOSPHOENOLPYRUVATE                  1.719932e-12
# PYRUVATE                             1.271402e-15
# SEDOHEPTULOSE_7-PHOSPHATE            1.000000e-05
# SUCCINATE                            5.665569e-08
# SUCCINATE_SEMIALDEHYDE               4.973678e-21
# SUCCINYL-COA                         1.196840e-06
# dtype: float64

# %% [markdown]
# ### Find Active and Variable Metabolites

# %%
 #Find active reactions, find chemicals that are in at least one reaction. Includes chemicals that are fixed as well as
# variable ones:
S_active = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.mat',header=0, index_col = 0, quoting=2)
del S_active['forward reaction']

active_metabolites_idx = (S_active != 0).any(axis=0) #any searches down the column
inactive_metabolites_idx = ~active_metabolites_idx

metabolites_status = pd.read_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.rstrt',delimiter = '\t', index_col=0,skiprows = 2, header=None,quoting=2,usecols=[0,2])
metabolites_status.rename(columns={2:'Value'},inplace=True)
metabolites_status.index = metabolites_status.index.str.strip()
metabolites_status['Variable?'] = metabolites_status == 'V'
metabolites_status.insert(1,'Active?',active_metabolites_idx.values)
del metabolites_status['Value']

metabolites_status['Variable & Active'] = metabolites_status['Variable?']&metabolites_status['Active?']
variable_metabolite_idx = list(metabolites_status[metabolites_status['Variable & Active']==True].index)
variable_metabolite_idx = list(map(str.strip, variable_metabolite_idx))
variable_metabolite_idx
# Out:
# ['2-OXOGLUTARATE',
#  '2-PHOSPHO-D-GLYCERATE',
#  '3-PHOSPHO-D-GLYCERATE',
#  '3-PHOSPHO-D-GLYCEROYL_PHOSPHATE',
#  '6-PHOSPHO_D-GLUCONO-1,5-LACTONE',
#  'ACETYL-COA',
#  'ALPHA-D-RIBOSE_5-PHOSPHATE',
#  'BETA-D-FRUCTOFURANOSE_6-PHOSPHATE',
#  'CIS-ACONITATE',
#  'CITRATE',
#  'D-ERYTHROSE_4-PHOSPHATE',
#  'D-GLUCONATE_6-PHOSPHATE',
#  'D-GLUCOPYRANOSE_6-PHOSPHATE',
#  'D-GLYCERALDEHYDE_3-PHOSPHATE',
#  'D-RIBULOSE_5-PHOSPHATE',
#  'D-THREO-ISOCITRATE',
#  'FRUCTOSE_1,6-BISPHOSPHATE',
#  'FUMARATE',
#  'GLYCERONE_PHOSPHATE',
#  'GLYOXYLATE',
#  'MALATE',
#  'OXALOACETATE',
#  'PHOSPHOENOLPYRUVATE',
#  'PYRUVATE',
#  'SEDOHEPTULOSE_7-PHOSPHATE',
#  'SUCCINATE',
#  'SUCCINATE_SEMIALDEHYDE',
#  'SUCCINYL-COA']

# %% [markdown]
# ### S.dot.net_likelihoods_steady_state

# %%
S = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.mat',header=0, index_col = 0, quoting=2)
del S['forward reaction']

S = S[~S.index.duplicated()].astype(np.float64)
# S.T.dot(ode_likelihoods_steadystate['For-Rev']) =  time derivative of concentrations
#                                                    0 at steady state and maximum entropy.
# If boundary conditions prevent maximum entropy, then the flux !=0 for boundary species.
derivatives2 = (S.T[ode_likelihoods_steadystate.index].dot(ode_likelihoods_steadystate['For-Rev'])).sort_values()
display(derivatives2[variable_metabolite_idx].sort_values().to_frame('Metabolite steady-state'))
# Out:
#                                    Metabolite steady-state
# PHOSPHOENOLPYRUVATE                          -6.222946e-07
# 3-PHOSPHO-D-GLYCERATE                        -6.000000e-07
# CITRATE                                      -4.062770e-07
# SUCCINATE                                    -2.000000e-07
# FRUCTOSE_1,6-BISPHOSPHATE                    -2.000000e-07
# MALATE                                       -9.999998e-08
# CIS-ACONITATE                                -4.700000e-08
# 2-OXOGLUTARATE                               -6.257999e-09
# PYRUVATE                                     -1.041141e-10
# D-GLUCOPYRANOSE_6-PHOSPHATE                  -8.881784e-16
# GLYOXYLATE                                    0.000000e+00
# D-ERYTHROSE_4-PHOSPHATE                       0.000000e+00
# D-GLUCONATE_6-PHOSPHATE                       0.000000e+00
# SUCCINATE_SEMIALDEHYDE                        0.000000e+00
# D-RIBULOSE_5-PHOSPHATE                        0.000000e+00
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE               0.000000e+00
# SEDOHEPTULOSE_7-PHOSPHATE                     0.000000e+00
# ALPHA-D-RIBOSE_5-PHOSPHATE                    0.000000e+00
# GLYCERONE_PHOSPHATE                           0.000000e+00
# SUCCINYL-COA                                  2.264301e-08
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE             2.000000e-07
# OXALOACETATE                                  2.464770e-07
# D-GLYCERALDEHYDE_3-PHOSPHATE                  3.000000e-07
# 2-PHOSPHO-D-GLYCERATE                         4.224000e-07
# D-THREO-ISOCITRATE                            4.904150e-07
# ACETYL-COA                                    6.464757e-07
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE               7.000000e-07
# FUMARATE                                      7.518317e+00

# %% [markdown]
# ### Infer Regulated Reactions

# %%
ode_metabolites_steadystate = \
pd.DataFrame(data = ode_metabolites.iloc[-20:,:].mean(),columns=['ODE'])
ode_metabolites_steadystate.sort_values(by=['ODE'])
# Out:
#                                             ODE
# SUCCINATE_SEMIALDEHYDE             4.973678e-21
# PYRUVATE                           1.271402e-15
# ACETYL-COA                         2.055541e-14
# 2-OXOGLUTARATE                     5.847891e-14
# PHOSPHOENOLPYRUVATE                1.719932e-12
# CIS-ACONITATE                      1.169665e-11
# SUCCINATE                          5.665569e-08
# GLYOXYLATE                         2.536081e-07
# SUCCINYL-COA                       1.196840e-06
# NADP+                              2.100000e-06
# D-XYLULOSE_5-PHOSPHATE             2.320598e-06
# SEDOHEPTULOSE_7-PHOSPHATE          1.000000e-05
# ALPHA-D-RIBOSE_5-PHOSPHATE         1.000000e-05
# D-ERYTHROSE_4-PHOSPHATE            1.000000e-05
# D-GLUCONATE_6-PHOSPHATE            1.000000e-05
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE    1.000000e-05
# FUMARATE                           1.000000e-05
# D-RIBULOSE_5-PHOSPHATE             1.000000e-05
# D-THREO-ISOCITRATE                 3.291877e-05
# D-GLYCERALDEHYDE_3-PHOSPHATE       3.955022e-05
# NADH                               8.300000e-05
# CO2                                1.000000e-04
# NADPH                              1.200000e-04
# ADP                                5.600000e-04
# AN_ELECTRON-TRANSFER_QUINONE       1.000000e-03
# AN_ELECTRON-TRANSFER_QUINOL        1.000000e-03
# COA                                1.400000e-03
# D-GLUCOPYRANOSE                    2.000000e-03
# NAD+                               2.600000e-03
# GLYCERONE_PHOSPHATE                3.485055e-03
# OXALOACETATE                       3.700555e-03
# ATP                                9.600000e-03
# ORTHOPHOSPHATE                     2.000000e-02
# 2-PHOSPHO-D-GLYCERATE              1.899655e+00
# MALATE                             1.915357e+01
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE  4.897343e+01
# D-GLUCOPYRANOSE_6-PHOSPHATE        7.862738e+01
# 3-PHOSPHO-D-GLYCERATE              1.568910e+02
# CITRATE                            2.318089e+02
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE    7.713808e+02
# FRUCTOSE_1,6-BISPHOSPHATE          2.530801e+06

# %%
ode_metabolites_steadystate['Expected'] = 1.0e-03

S = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.mat',header=0, index_col = 0, quoting=2)
P = (S>0)
P = P[~P.index.duplicated()].astype(np.float64)
del P['forward reaction']
#S.T[ode_likelihoods_steadystate.index].dot(ode_likelihoods_steadystate['For-Rev'])).sort_values()
P = P.astype(np.float64)
#display(R)
product_concentrations = P.multiply(ode_metabolites_steadystate['ODE'],axis=1)
product_concentrations[product_concentrations == 0] = 1
product_concentrations_rxns = pd.DataFrame(data = product_concentrations.T.product(), columns=['ODE'])
expect_product_concentrations = P.multiply(ode_metabolites_steadystate['Expected'],axis=1)
expect_product_concentrations[expect_product_concentrations == 0] = 1
product_concentrations_rxns['Expected'] = (expect_product_concentrations.T).product()

s_regulation = '$\Delta S_{reg}$'
product_concentrations_rxns[s_regulation] = \
    np.log(product_concentrations_rxns['ODE']/product_concentrations_rxns['Expected'])

idx = (ode_likelihoods_steadystate['Reverse'] != 0) & (ode_likelihoods_steadystate['Forward'] != 0) & \
            (product_concentrations_rxns[s_regulation]>1)
#display(product_concentrations_rxns[product_concentrations_rxns[s_regulation]>1])

display(product_concentrations_rxns[idx].sort_values(by=s_regulation))
product_concentrations_rxns[idx].to_csv(path_or_buf='loss_no_regulation1.txt',sep='\t')
# Out:
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/ipykernel/__main__.py:23 UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                          ODE      Expected  $\Delta S_{reg}$
# reaction title
# FUMm            1.915357e-07  1.000000e-09          5.255074
# PGM             1.899655e+00  1.000000e-03          7.549428
# MALSp           2.681500e-02  1.000000e-06         10.196717
# HEX1            4.403133e-02  1.000000e-06         10.692657
# PGI             4.897343e+01  1.000000e-03         10.799033
# G6PIh           6.402461e-02  1.000000e-06         11.067023
# CS              3.245325e-01  1.000000e-06         12.690141
# PGKm            1.506154e+00  1.000000e-06         14.225070
# PFKh            1.417249e+03  1.000000e-06         21.071983
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/ipykernel/__main__.py:24 UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ## Likelihoods from Stochastic Simulation
# *The average values aren't correct because they don't consider how much relative time was spent in each configuration*

# %%
# Read boltzmann stochastic reaction likelihoods
from IPython.display import display
fwd_columns = np.arange(3,20,2)
rev_columns = np.arange(4,20,2)
stoch_fwd_likelihoods = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.lklhd',header=1, usecols=fwd_columns,quoting=2)
stoch_rev_likelihoods = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.lklhd',header=1, usecols=rev_columns,quoting=2)

column_names = [x.split("f_")[-1] for x in stoch_fwd_likelihoods.columns]
stoch_fwd_likelihoods.columns = column_names
column_names = [x.split("r_")[-1] for x in stoch_rev_likelihoods.columns]
stoch_rev_likelihoods.columns = column_names

plt.figure();
stoch_fwd_likelihoods[''].plot(legend=True,logy=False,logx=True,figsize=(12, 12))
plt.yscale('symlog')
#plt.plot(stoch_likelihoods,legend=True)
# plt.plot(stoch_likelihoods,legend=True,logy=True,figsize=(12, 12))
plt.legend(bbox_to_anchor=(1.02, 0.9),bbox_transform=plt.gcf().transFigure)

display(stoch_fwd_likelihoods.iloc[-10000:-1].mean() - stoch_rev_likelihoods.iloc[-10000:-1].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-6e035bcb304d> in <module>()
#      12
#      13 plt.figure();
# ---> 14 stoch_fwd_likelihoods[''].plot(legend=True,logy=False,logx=True,figsize=(12, 12))
#      15 plt.yscale('symlog')
#      16 #plt.plot(stoch_likelihoods,legend=True)
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''

# %% [markdown]
# ## Read in Flux Values from Stochastic Simulation

# %%
#columns = ["Reaction","Description","Flux","Net Flux"]
columns = [0, 3]
skip = np.arange(0,56,2)
stoch_flux = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.view', sep='\t',index_col=[0], header=None, 
                           usecols=columns,quoting=2,skiprows = skip)
stoch_flux.columns=["Net Flux"]
stoch_flux['Rxn Probability'] = stoch_flux['Net Flux']/np.sum(abs(stoch_flux['Net Flux'].values))
stoch_flux
# Out:
#                           Net Flux  Rxn Probability
# 0
# PGI                   4.636759e+18     6.666567e-02
# PFKh                  4.636759e+18     6.666567e-02
# BFBPh                 4.636766e+18     6.666577e-02
# FBAF                  4.636774e+18     6.666589e-02
# TPI                   4.636781e+18     6.666599e-02
# G6PIh                 4.636851e+18     6.666700e-02
# PGKm                  4.636851e+18     6.666700e-02
# PGM                   4.636851e+18     6.666700e-02
# ENOf                  4.636851e+18     6.666700e-02
# PYKf                  4.636851e+18     6.666700e-02
# PDHm                  4.636851e+18     6.666700e-02
# CS                    4.636851e+18     6.666700e-02
# ACONITATEDEHYDR__RXN  4.636851e+18     6.666700e-02
# ACONITATEHYDR__RXN    4.636851e+18     6.666700e-02
# ICDHxm                4.636921e+18     6.666801e-02
# ISOCIT__CLEAV__RXN    3.700000e+01     5.319729e-19
# MALSp                 0.000000e+00     0.000000e+00
# OXGDC                 0.000000e+00     0.000000e+00
# AKGDm                 4.250000e+02     6.110499e-18
# SUCOAS                7.690000e+02     1.105641e-17
# FUMm                  8.190000e+02     1.177529e-17
# MDHm                  7.970000e+02     1.145898e-17
# G6PDH2r               0.000000e+00     0.000000e+00
# PGLh                  0.000000e+00     0.000000e+00
# PGDHh                 0.000000e+00     0.000000e+00
# RPEh                  0.000000e+00     0.000000e+00
# RPI                   0.000000e+00     0.000000e+00
# TKT1                  0.000000e+00     0.000000e+00
# TKT1                  0.000000e+00     0.000000e+00
# TALA                  0.000000e+00     0.000000e+00
# TALA                  0.000000e+00     0.000000e+00
# TKT2                  0.000000e+00     0.000000e+00
# TKT2                  0.000000e+00     0.000000e+00
# PGI                   0.000000e+00     0.000000e+00
# PGI                   0.000000e+00     0.000000e+00

# %% [markdown]
# ## Analyze Metabolite Levels from Stochastic Simulation

# %%
# Read boltzmann stochastic reaction likelihoods
columns = np.arange(1,57,1)
stoch_metabolites = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.concs',header=0,index_col=0)

plt.figure();stoch_metabolites.plot(legend=True,logy=True,figsize=(12, 12))
plt.legend(bbox_to_anchor=(1.3, 0.92),bbox_transform=plt.gcf().transFigure)

# %%
stoch_metabolites.iloc[-100:,:].mean()
# Out:
# 2-OXOGLUTARATE                       1.743545e-09
# 2-PHOSPHO-D-GLYCERATE                2.579192e+00
# 3-PHOSPHO-D-GLYCERATE                2.868683e+02
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE      1.899456e+03
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE      6.084639e-05
# ACETYL-COA                           1.195574e-09
# ADP                                  5.600000e-04
# ALPHA-D-RIBOSE_5-PHOSPHATE           9.999644e-06
# AN_ELECTRON-TRANSFER_QUINOL          9.999993e-04
# AN_ELECTRON-TRANSFER_QUINONE         9.999993e-04
# ATP                                  9.600001e-03
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE    9.437467e-04
# CIS-ACONITATE                        1.726940e-09
# CITRATE                              3.164689e+02
# CO2                                  9.999976e-05
# COA                                  1.400000e-03
# D-ERYTHROSE_4-PHOSPHATE              9.999644e-06
# D-GLUCONATE_6-PHOSPHATE              1.999929e-05
# D-GLUCOPYRANOSE_6-PHOSPHATE          2.000000e-03
# D-GLYCERALDEHYDE_3-PHOSPHATE         1.127824e-07
# D-RIBULOSE_5-PHOSPHATE               0.000000e+00
# D-THREO-ISOCITRATE                   4.465480e-05
# D-XYLULOSE_5-PHOSPHATE               2.321405e-06
# FRUCTOSE_1,6-BISPHOSPHATE            3.695104e+01
# FUMARATE                             9.999644e-06
# GLYCERONE_PHOSPHATE                  1.330489e-05
# GLYOXYLATE                           2.240704e-07
# MALATE                               2.311742e+01
# NAD+                                 2.600001e-03
# NADH                                 8.299937e-05
# NADP+                                2.100556e-06
# NADPH                                1.200007e-04
# ORTHOPHOSPHATE                       2.000000e-02
# OXALOACETATE                         3.317180e-03
# PHOSPHOENOLPYRUVATE                  1.726940e-09
# PYRUVATE                             1.726940e-09
# SEDOHEPTULOSE_7-PHOSPHATE            9.999644e-06
# SUCCINATE                            7.819383e-08
# SUCCINATE_SEMIALDEHYDE               0.000000e+00
# SUCCINYL-COA                         2.026580e-06
# dtype: float64

# %% [markdown]
# ## Compare ODE and Stochastic Metabolite Concentrations

# %%
stoch_metabolites.iloc[-100:,:].mean()/ode_metabolites.iloc[-1:,:].mean()
# Out:
# 2-OXOGLUTARATE                       9.103147e+03
# 2-PHOSPHO-D-GLYCERATE                1.000000e+00
# 3-PHOSPHO-D-GLYCERATE                1.000000e+00
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE      1.000000e+00
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE      1.000012e+00
# ACETYL-COA                           2.813277e+04
# ADP                                  1.000000e+00
# ALPHA-D-RIBOSE_5-PHOSPHATE           9.999644e-01
# AN_ELECTRON-TRANSFER_QUINOL          9.999993e-01
# AN_ELECTRON-TRANSFER_QUINONE         9.999993e-01
# ATP                                  1.000000e+00
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE    9.999606e-01
# CIS-ACONITATE                        8.014672e+01
# CITRATE                              1.000000e+00
# CO2                                  9.999976e-01
# COA                                  1.000000e+00
# D-ERYTHROSE_4-PHOSPHATE              9.999644e-01
# D-GLUCONATE_6-PHOSPHATE              9.999645e-01
# D-GLUCOPYRANOSE_6-PHOSPHATE          1.000000e+00
# D-GLYCERALDEHYDE_3-PHOSPHATE         9.990429e-01
# D-RIBULOSE_5-PHOSPHATE               0.000000e+00
# D-THREO-ISOCITRATE                   9.993994e-01
# D-XYLULOSE_5-PHOSPHATE               1.000348e+00
# FRUCTOSE_1,6-BISPHOSPHATE            1.000000e+00
# FUMARATE                             9.999644e-01
# GLYCERONE_PHOSPHATE                  9.991817e-01
# GLYOXYLATE                           1.053218e+00
# MALATE                               1.000000e+00
# NAD+                                 1.000000e+00
# NADH                                 9.999924e-01
# NADP+                                1.000265e+00
# NADPH                                1.000006e+00
# ORTHOPHOSPHATE                       1.000000e+00
# OXALOACETATE                         1.000197e+00
# PHOSPHOENOLPYRUVATE                  7.398017e+02
# PYRUVATE                             1.000779e+06
# SEDOHEPTULOSE_7-PHOSPHATE            9.999644e-01
# SUCCINATE                            8.496697e-01
# SUCCINATE_SEMIALDEHYDE               0.000000e+00
# SUCCINYL-COA                         7.827802e-01
# dtype: float64

# %% [markdown]
# ## Display Pathway Predictions

# %%
from escher import Builder

reaction_data = (stoch_flux['Net Flux'].to_dict())
#reaction_data = (ode_likelihoods_timeseries.iloc[-1]).to_dict()
#for x in reaction_data.keys():
#  y = x.split("f_")[-1]
#  reaction_data[y] = reaction_data.pop(x)
b = Builder(map_name="e_coli_core.Core metabolism",reaction_data=reaction_data)
b.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="ejpivulojx"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"ejpivulojx"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"RXN0__45__1132": 4.619808448510388e+18, "_3PGAREARR__45__RXN": 4.619808448510388e+18, "RXN__45__12959": 0.0, "PLASTOQUINOL__45____45__PLASTOCYANIN__45__REDUCTASE__45__RXN": 4.619808448510388e+18, "ISOCITRATE__45__DEHYDROGENASE__45__NAD__43____45__RXN": 4.619808448510388e+18, "RXN__45__9952": 4.619808448510388e+18, "RXN0__45__1134": 4.619808448510388e+18, "ACONITATEDEHYDR__45__RXN": 4.619808448510388e+18, "TRANSALDOL__45__RXN": 4.619808448510388e+18, "RXN0__45__1133": 4.619808448510388e+18, "RXN__45__1381": 0.0, "F16BDEPHOS__45__RXN": 0.0, "RXN__45__1641": 0.0, "MALATE__45__DEH__45__RXN": 4.619808448510388e+18, "GAPOXNPHOSPHN__45__RXN": 4.619808448510388e+18, "SEDOHEPTULOSE__45__BISPHOSPHATASE__45__RXN": 0.0, "RXN__45__1623": 0.0, "SEDOBISALDOL__45__RXN": 0.0, "_1TRANSKETO__45__RXN": 0.0, "RXN__45__15513": 4.619808448510388e+18, "ACONITATEHYDR__45__RXN": 4.619808448510388e+18, "_6PGLUCONOLACT__45__RXN": 4.619808448510388e+18, "_1__46__1__46__1__46__8__45__RXN": -4.62081378304968e+18, "_2PGADEHYDRAT__45__RXN": 4.619808448510388e+18, "RXN__45__15479": 4.619808448510388e+18, "PHOSPHORIBULOKINASE__45__RXN": 0.0, "RIB5PISOM__45__RXN": 0.0, "_1__46__2__46__1__46__13__45__RXN": 0.0, "DIACYLGLYCEROL__45__O__45__ACYLTRANSFERASE__45__RXN": 0.0, "TRIOSEPISOMERIZATION__45__RXN": 0.0, "F16ALDOLASE__45__RXN": 0.0, "PSII__45__RXN": 4.619808448510388e+18, "_2TRANSKETO__45__RXN": 0.0, "FUMHYDR__45__RXN": 4.619808448510388e+18, "PEPSYNTH__45__RXN": -4.619808448510388e+18, "PEPDEPHOS__45__RXN": 4.619808448510388e+18, "RXN__45__15745": 0.0, "PHOSGLYPHOS__45__RXN": 0.0, "RIBULP3EPIM__45__RXN": 0.0, "_6PFRUCTPHOS__45__RXN": 4.619808448510388e+18, "PGLUCISOM__45__RXN": 4.619808448510388e+18, "RXN__45__14971": 4.619808448510388e+18, "CITSYN__45__RXN": 4.619808448510388e+18, "PHOSPHATIDATE__45__PHOSPHATASE__45__RXN": 0.0, "_2OXOGLUTARATEDEH__45__RXN": 4.619808448510388e+18, "RIBULOSE__45__BISPHOSPHATE__45__CARBOXYLASE__45__RXN": 0.0, "RXN__45__12383": 0.0, "GLU6PDEHYDROG__45__RXN": 4.619808448510388e+18, "SUCCCOASYN__45__RXN": 4.619808448510388e+18, "_1__46__18__46__1__46__2__45__RXN": 4.619808448510388e+18}, "enable_editing": false, "gene_data": null, "metabolite_data": null, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name": "e_coli_core.Core metabolism", "map_id": "0df3827fde8464e80f455a773a52c274", "map_description": "E. coli core metabolic network\\nLast Modified Fri Dec 05 2014 16:39:44 GMT-0800 (PST)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"1577514": {"name": "Formate transport in via proton symport", "bigg_id": "FORt2", "segments": {"11": {"to_node_id": "1577044", "from_node_id": "1576666", "b2": {"y": 4749.209372712298, "x": 1360.0}, "b1": {"y": 4827.353507999329, "x": 1360.0}}, "10": {"to_node_id": "1577046", "from_node_id": "1577045", "b2": null, "b1": null}, "13": {"to_node_id": "1576590", "from_node_id": "1577046", "b2": {"y": 4275.94781629675, "x": 1360.0}, "b1": {"y": 4411.784344889025, "x": 1360.0}}, "12": {"to_node_id": "1577044", "from_node_id": "1576833", "b2": {"y": 4744.773286702694, "x": 1360.0}, "b1": {"y": 4779.244289008981, "x": 1360.0}}, "14": {"to_node_id": "1576811", "from_node_id": "1577046", "b2": {"y": 4422.5658350974745, "x": 1360.0}, "b1": {"y": 4455.769750529243, "x": 1360.0}}, "9": {"to_node_id": "1577045", "from_node_id": "1577044", "b2": null, "b1": null}}, "genes": [{"bigg_id": "b2492", "name": "focB"}, {"bigg_id": "b0904", "name": "focA"}], "reversibility": false, "metabolites": [{"coefficient": -1.0, "bigg_id": "for_e"}, {"coefficient": 1.0, "bigg_id": "h_c"}, {"coefficient": 1.0, "bigg_id": "for_c"}, {"coefficient": -1.0, "bigg_id": "h_e"}], "label_x": 1255.7530517578125, "label_y": 4574.13232421875, "gene_reaction_rule": "b0904 or b2492"}, "1577518": {"name": "Formate transport via diffusion", "bigg_id": "FORti", "segments": {"15": {"to_node_id": "1577047", "from_node_id": "1576590", "b2": {"y": 4263.5, "x": 1460.0}, "b1": {"y": 4145.55, "x": 1460.0}}, "16": {"to_node_id": "1576666", "from_node_id": "1577047", "b2": {"y": 4654.322265625, "x": 1460.0}, "b1": {"y": 4488.7, "x": 1460.0}}}, "genes": [{"bigg_id": "b2492", "name": "focB"}, {"bigg_id": "b0904", "name": "focA"}], "reversibility": false, "metabolites": [{"coefficient": 1.0, "bigg_id": "for_e"}, {"coefficient": -1.0, "bigg_id": "fo

# %% [markdown]
# ## Power and Fluxes

# %%
# Read boltzmann stochastic reaction likelihoods
ode_metabolites = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_concs',header=0,index_col=0)
#column_names = [x.split(":")[0] for x in ode_metabolites.columns]
#column_names = [x.split(":")[0] for x in ode_metabolites.columns]
#ode_metabolites.columns = column_names

plt.figure();ode_metabolites.plot(legend=False,logx=True,logy=True,figsize=(10, 10))
#plt.legend(bbox_to_anchor=(1.35, 0.95),bbox_transform=plt.gcf().transFigure)

# %%
#ode_metabolites_steadystate = pd.DataFrame()
ode_metabolites_steadystate = \
  pd.DataFrame(data = ode_metabolites.iloc[-20:,:].mean(axis=0),columns=['Mean'])
ode_metabolites_steadystate['CV'] = \
  pd.DataFrame(data = ode_metabolites.iloc[-20:,:].var(axis=0)/ode_metabolites.iloc[-20:,:].mean(axis=0),columns=['ODE'])
ode_metabolites_steadystate['Ratio'] = \
  pd.DataFrame(data =(ode_metabolites.iloc[-1]/ode_metabolites.iloc[0]))


ode_metabolites_steadystate

#ode_metabolites.iloc[-1,:]
# Out:
#                                            Mean            CV     Ratio
# 2-OXOGLUTARATE                     5.847891e-14  2.867596e-45       inf
# 2-PHOSPHO-D-GLYCERATE              1.899655e+00  0.000000e+00  1.000000
# 3-PHOSPHO-D-GLYCERATE              1.568910e+02  5.419744e-30  1.000000
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE    7.713808e+02  1.587342e-28  1.000000
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE    1.000000e-05  0.000000e+00  1.000000
# ACETYL-COA                         2.055541e-14  4.588953e-45  0.000001
# ADP                                5.600000e-04  2.209576e-35  1.000000
# ALPHA-D-RIBOSE_5-PHOSPHATE         1.000000e-05  0.000000e+00  1.000000
# AN_ELECTRON-TRANSFER_QUINOL        1.000000e-03  1.979780e-34  1.000000
# AN_ELECTRON-TRANSFER_QUINONE       1.000000e-03  1.979780e-34  1.000000
# ATP                                9.600000e-03  0.000000e+00  1.000000
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE  4.897343e+01  0.000000e+00  1.000000
# CIS-ACONITATE                      1.169665e-11  2.114064e-42  0.007139
# CITRATE                            2.318089e+02  0.000000e+00  1.000000
# CO2                                1.000000e-04  1.933379e-36  1.000000
# COA                                1.400000e-03  3.181789e-34  1.000000
# D-ERYTHROSE_4-PHOSPHATE            1.000000e-05  0.000000e+00  1.000000
# D-GLUCONATE_6-PHOSPHATE            1.000000e-05  0.000000e+00  1.000000
# D-GLUCOPYRANOSE                    2.000000e-03  3.959560e-34  1.000000
# D-GLUCOPYRANOSE_6-PHOSPHATE        7.862738e+01  1.081441e-29  1.000000
# D-GLYCERALDEHYDE_3-PHOSPHATE       3.955022e-05  1.099893e-35  0.997529
# D-RIBULOSE_5-PHOSPHATE             1.000000e-05  0.000000e+00  1.000000
# D-THREO-ISOCITRATE                 3.291877e-05  1.468295e-36  1.002325
# D-XYLULOSE_5-PHOSPHATE             2.320598e-06  8.136115e-38  1.000000
# FRUCTOSE_1,6-BISPHOSPHATE          2.530801e+06  0.000000e+00  1.000000
# FUMARATE                           1.000000e-05  0.000000e+00  1.000000
# GLYCERONE_PHOSPHATE                3.485055e-03  0.000000e+00  1.000003
# GLYOXYLATE                         2.536081e-07  0.000000e+00  1.034028
# MALATE                             1.915357e+01  0.000000e+00  1.000000
# NAD+                               2.600000e-03  3.045815e-34  1.000000
# NADH                               8.300000e-05  9.317489e-36  1.000000
# NADP+                              2.100000e-06  8.990787e-38  1.000000
# NADPH                              1.200000e-04  1.611149e-36  1.000000
# ORTHOPHOSPHATE                     2.000000e-02  6.335296e-34  1.000000
# OXALOACETATE                       3.700555e-03  0.000000e+00  0.999964
# PHOSPHOENOLPYRUVATE                1.719932e-12  9.984031e-44  0.001037
# PYRUVATE                           1.271402e-15  1.288055e-46       inf
# SEDOHEPTULOSE_7-PHOSPHATE          1.000000e-05  0.000000e+00  1.000000
# SUCCINATE                          5.665569e-08  8.136049e-40  0.895067
# SUCCINATE_SEMIALDEHYDE             4.973678e-21  1.078058e-51  0.002854
# SUCCINYL-COA                       1.196840e-06  3.943855e-38  1.444718

# %%
S = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.mat',header=0, index_col = 0, quoting=2)
R = (S<0)
P = S>0
del R['forward reaction']
del P['forward reaction']
del S['forward reaction']
#S['H2O:CYTOSOL'] =0
#S['H2O:GLYOXYSOME'] =0
#S['H2O:MITOCHONDRIA'] =0

volume_coeff = S.sum(axis=1)

R = R.astype(np.float64)
P = P.astype(np.float64)

steadyState_counts = ode_metabolites_steadystate['Mean']*Concentration2Count

reactant_counts = R.multiply(steadyState_counts,axis=1)
reactant_concs =  R.multiply(ode_metabolites_steadystate['Mean'])
product_counts = P.multiply(steadyState_counts,axis=1)
product_concs = P.multiply(ode_metabolites_steadystate['Mean'])

product_counts_incremented = product_counts + P.multiply(1)
product_concs_incremented = product_concs + P.multiply(concentration_increment)
product_counts = product_counts #+ P.multiply(1)
product_concs = product_concs #+ P.multiply(concentration_increment)

# Take the product of counts of all reactants for a reaction
reactant_counts_rxns = (reactant_counts[reactant_counts != 0].T).product()
reactant_concs_rxns = (reactant_concs[reactant_concs != 0].T).product()

# Take the product of counts of all products for a reaction
product_counts_rxns = (product_counts[product_counts != 0].T).product()
product_concs_rxns = (product_concs[product_concs != 0].T).product()
product_counts_incremented_rxns = (product_counts_incremented[product_counts_incremented != 0].T).product()
product_concs_incremented_rxns = (product_concs_incremented[product_concs_incremented != 0].T).product()
#denominator = reactant_counts_rxns.multiply(1-ode_likelihoods_steadystate['Reverse'])

K_eq = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.dg0ke',header=0, index_col = 0, quoting=2)

result = pd.DataFrame()
result['Boltzmann Ke'] = K_eq['Ke']
# Notice that Computed L_fwd uses incremented product counts. That is so we can compare to Boltzmann values
# when calculating the activities. That is, these need to use the same formula.
result['Computed L_fwd'] = result['Boltzmann Ke'].multiply(reactant_counts_rxns.divide(product_counts_incremented_rxns))
display(result)

idx = np.abs(ode_likelihoods_steadystate['For-Rev']) > 0
DeltaG = "$\Delta G$"
ode_likelihoods_steadystate[DeltaG] = np.nan
ode_likelihoods_steadystate['Power'] = np.nan
ode_likelihoods_steadystate[DeltaG][idx] = -RT*np.log(result['Computed L_fwd'][idx])
ode_likelihoods_steadystate['Power'][idx] = ode_likelihoods_steadystate['For-Rev'][idx]*np.log(result['Computed L_fwd'][idx])
display(ode_likelihoods_steadystate)
# Out:
#                     Boltzmann Ke  Computed L_fwd
# Rxn_title
# HEX1                9.192989e+03    4.008620e+00
# PGI                 2.496788e+00    4.008621e+00
# PFKh                1.208399e+04    4.008619e+00
# BFBPh               6.197753e-02    2.659199e-04
# FBAF                1.314828e-04    4.008658e+00
# TPI                 4.549371e-02    4.008610e+00
# G6PIh               3.954160e-01    7.648949e+00
# PGKm                2.666982e+01    7.649052e+00
# PGM                 9.261562e-02    7.649051e+00
# ENOf                3.961900e+00    4.527720e+09
# PYKf                1.244333e+05    7.518223e+00
# PDHm                2.239131e+04    7.518225e+00
# CS                  5.326355e+07    1.248431e-08
# ACONTa              3.266575e-02    4.528196e+09
# ACONITATEHYDR__RXN  3.514164e-02    1.248585e-08
# ICDHxm              7.291438e-01    7.518321e+00
# ISOCIT__CLEAV__RXN  2.675459e-01    9.824356e-01
# MALSp               2.995393e+07    5.823241e-12
# OXGDC               1.756270e+01    1.027030e-08
# AKGDm               3.513601e+05    7.518321e+00
# SUCOAS              4.470177e-01    7.645212e+00
# FUMm                4.292596e+00    2.108095e-12
# MDHm                4.717787e-05    7.649051e+00
# G6PDH2r             1.737796e+00    2.390741e+05
# PGLh                1.943966e+01    1.943643e+01
# PGDHh               1.747861e+00    5.078187e-07
# RPEh                1.000000e+00    4.306153e+00
# RPI                 8.306288e-01    8.304909e-01
# TKT1                1.076262e+00    1.832670e+01
# TALA                3.264645e+01    2.636041e-05
# TKT2                1.503324e-01    1.801046e-09
# HEX1                1.000000e+00    1.000000e+00
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-48-3a0a86738ee9> in <module>()
#      50 ode_likelihoods_steadystate[DeltaG] = np.nan
#      51 ode_likelihoods_steadystate['Power'] = np.nan
# ---> 52 ode_likelihoods_steadystate[DeltaG][idx] = -RT*np.log(result['Computed L_fwd'][idx])
#      53 ode_likelihoods_steadystate['Power'][idx] = ode_likelihoods_steadystate['For-Rev'][idx]*np.log(result['Computed L_fwd'][idx])
#      54 display(ode_likelihoods_steadystate)
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     660
#     661         if com.is_bool_indexer(key):
# --> 662             key = check_bool_indexer(self.index, key)
#     663
#     664         return self._get_with(key)
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/indexing.pyc in check_bool_indexer(ax, key)
#    2021         mask = isna(result._values)
#    2022         if mask.any():
# -> 2023             raise IndexingError('Unalignable boolean Series provided as '
#    2024                                 'indexer (index of the boolean Series and of '
#    2025                                 'the indexed object do not match')
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match

# %% [markdown]
# # Boltzmann to sbml file for biocyc

# %%
import pandas as pd
import numpy as np
import re, os
def to_chr(  matchobj ):
        return chr(int(matchobj.group(1)))
def to_ord( matchobj ):
        return '__{}__'.format(ord(matchobj.group(0)))    
def munge( sbmlid ):
    alphaRE = re.compile(r'[^A-Za-z_]')
    m = alphaRE.match(sbmlid[0])
    if m:
        sbmlid = '_{}'.format(sbmlid)
    alphanumRE = re.compile(r'[^A-Za-z0-9_]')
    sbmlid = alphanumRE.sub(to_ord, sbmlid)
    return sbmlid
def unmunge( sbmlid ):
    ordRE = re.compile('__([0-9]+)__')
    if '_' == sbmlid[0] and '_' != sbmlid[1]:
        sbmlid = sbmlid[1:]
    return ordRE.sub( to_chr, sbmlid)    
def unmunge_model( model ):     
    for met in model.metabolites:
        met.id = unmunge(met.id)
    for rxn in model.reactions:
        rxn.id = unmunge(rxn.id)
    return model

# %%
concs = pd.read_table('central_metabolism_dg0_rxns_GLy.ode_concs',index_col=0)#.apply(np.log)
log_concs = concs.apply(np.log).T
log_concs.index
mets = {'2-PHOSPHO-D-GLYCERATE':'2-PG', 
        '3-PHOSPHO-D-GLYCERATE':'G3P',
        '3-PHOSPHO-D-GLYCEROYL_PHOSPHATE':'DPG', 
        'ADP':'ADP', 
        'AMP':'AMP', 
        'ATP':'ATP',
       'BETA-D-FRUCTOFURANOSE_6-PHOSPHATE':'FRUCTOSE-6P', 
        'D-GLUCOPYRANOSE_6-PHOSPHATE':'D-glucopyranose-6-phosphate',
       'D-GLYCERALDEHYDE_3-PHOSPHATE':'GAP', 
        'FRUCTOSE_1,6-BISPHOSPHATE':'FRUCTOSE-16-DIPHOSPHATE',
       'GLYCERONE_PHOSPHATE':'DIHYDROXY-ACETONE-PHOSPHATE', 
        'H+':'PROTON', 
        'NAD+':'NAD', 
        'NADH':'NADH', 
        'ORTHOPHOSPHATE':'Pi',
       'PHOSPHOENOLPYRUVATE':'PHOSPHO-ENOL-PYRUVATE', 
        'PYRUVATE':'PYRUVATE'}

log_concs.index = [mets[m] for m in log_concs.index]
log_concs.index.name='$Metabolite'

#log_concs[['0','10000']].to_csv('central_metabolism_dg0_rxns_GLy.log_concs.tab',sep='\t')
#log_concs
